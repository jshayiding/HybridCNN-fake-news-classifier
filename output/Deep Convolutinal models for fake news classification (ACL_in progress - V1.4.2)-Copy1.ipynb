# %%
## import dependencies
import pandas as pd
import numpy as np
import keras.utils
import nlp_util
from nltk.corpus import stopwords
import string
import re

from keras import backend as K

from keras.layers import Conv1D, Dense, Input, Lambda, LSTM
from keras.layers.merge import concatenate
from keras.layers.embeddings import Embedding

from keras.utils import to_categorical
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.text import text_to_word_sequence
from keras.preprocessing import sequence
import _pickle as cPickle

from keras.layers import Concatenate, Input, MaxPooling1D
from keras.models import Model
from keras.preprocessing.sequence import pad_sequences # To make vectors the same size. 
# from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Embedding
from keras.layers import Conv1D, GlobalMaxPool1D, MaxPool1D
from keras.optimizers import SGD
from keras.utils import to_categorical
from keras.optimizers import Adam
from keras.callbacks import TensorBoard, CSVLogger, EarlyStopping
import matplotlib.pyplot as plt

# %%
## load dataset
train_file=pd.read_csv('train.tsv', sep='\t', header=None, encoding='utf-8')
test_file=pd.read_csv('test.tsv', sep='\t', header=None, encoding='utf-8')
va_file=pd.read_csv('valid.tsv', sep='\t', header=None, encoding='utf-8')

column_names = ['Id', 'Label','Statement','Subject','Speaker','Speaker Job','State Info','Party','BT','FC','HT','MT','PF','Context']
train_file.columns, test_file.columns, va_file.columns=column_names, column_names, column_names

train_data = train_file[train_file.columns[~train_file.columns.isin(['Id','BT','FC','HT','MT','PF'])]]
test_data = test_file[test_file.columns[~test_file.columns.isin(['Id','BT','FC','HT','MT','PF'])]]
val_data = va_file[va_file.columns[~va_file.columns.isin(['Id','BT','FC','HT','MT','PF'])]]

# %%
train_data.head(3)
# Out:
#          Label                                          Statement  \
# 0        false  Says the Annies List political group supports ...
# 1    half-true  When did the decline of coal start? It started...
# 2  mostly-true  Hillary Clinton agrees with John McCain "by vo...
#
#                               Subject         Speaker           Speaker Job  \
# 0                            abortion    dwayne-bohac  State representative
# 1  energy,history,job-accomplishments  scott-surovell        State delegate
# 2                      foreign-policy    barack-obama             President
#
#   State Info       Party          Context
# 0      Texas  republican         a mailer
# 1   Virginia    democrat  a floor speech.
# 2   Illinois    democrat           Denver

# %%
multi_labels_dict = {'false':0, 'true':1,'pants-fire':2,'barely-true':3,'half-true':4,'mostly-true':5}
binary_labels = {'false':1, 'true':-1,'pants-fire':1,'barely-true':1,'half-true':0,'mostly-true':-1}


def one_hot_label(label):
    return to_categorical(multi_labels_dict[x], num_classes=6)

train_data['multi_label']=train_data['Label'].apply(lambda x: multi_labels_dict[x])
test_data['multi_label']=test_data['Label'].apply(lambda x: multi_labels_dict[x])
val_data['multi_label']=val_data['Label'].apply(lambda x: multi_labels_dict[x])
# Out:
# C:\Users\jshayi2\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\jshayi2\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# C:\Users\jshayi2\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.

# %% [markdown]
# ### Metadata processing

# %%
speakers= ['barack-obama', 'donald-trump', 'hillary-clinton', 'mitt-romney', 
                'scott-walker', 'john-mccain', 'rick-perry', 'chain-email', 
                'marco-rubio', 'rick-scott', 'ted-cruz', 'bernie-s', 'chris-christie', 
                'facebook-posts', 'charlie-crist', 'newt-gingrich', 'jeb-bush', 
                'joe-biden', 'blog-posting','paul-ryan']

speaker_dict={}
for cnt, speaker in enumerate(speakers):
    speaker_dict[speaker]=cnt
print(speaker_dict)

def speaker_projection(speaker):
    if isinstance(speaker, str):
        speaker=speaker.lower()
        matched=[s for s in speakers if s in speaker]
        if len(matched)>0:
            return speaker_dict[matched[0]]
        else:
            return len(speakers)
        
##
train_data['speaker_id']=train_data['Speaker'].apply(speaker_projection)
test_data['speaker_id']=test_data['Speaker'].apply(speaker_projection)
val_data['speaker_id']=val_data['Speaker'].apply(speaker_projection)
# Out:
# {'barack-obama': 0, 'donald-trump': 1, 'hillary-clinton': 2, 'mitt-romney': 3, 'scott-walker': 4, 'john-mccain': 5, 'rick-perry': 6, 'chain-email': 7, 'marco-rubio': 8, 'rick-scott': 9, 'ted-cruz': 10, 'bernie-s': 11, 'chris-christie': 12, 'facebook-posts': 13, 'charlie-crist': 14, 'newt-gingrich': 15, 'jeb-bush': 16, 'joe-biden': 17, 'blog-posting': 18, 'paul-ryan': 19}
# C:\Users\jshayi2\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\jshayi2\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\jshayi2\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
## Map job
job_list = ['president', 'u.s. senator', 'governor', 'president-elect', 'presidential candidate', 
                'u.s. representative', 'state senator', 'attorney', 'state representative', 'congress', 'others']


job_dict = {'president':0, 'u.s. senator':1, 'governor':2, 'president-elect':3, 'presidential candidate':4, 
            'u.s. representative':5, 'state senator':6, 'attorney':7, 'state representative':8, 'congress':9, 'others':10}

## Map job

def job_projection(job):
    if isinstance(job, str):
        job=job.lower()
        matched_job=[j for j in job_list if j in job]
        if len(matched_job)>0:
            return job_dict[matched_job[0]]
        else:
            return 10
    else:
        return 10

## job projection output

train_data['job_id']=train_data['Speaker Job'].apply(job_projection)
test_data['job_id']=test_data['Speaker Job'].apply(job_projection)
val_data['job_id']=val_data['Speaker Job'].apply(job_projection)
# Out:
# C:\Users\jshayi2\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\jshayi2\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\jshayi2\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
### Map political parties
party_dict={'republican':0, 'democrat':1, 'none':2, 'organization':3, 'newsmaker':4, 'rest':5}

def map_political_party(party):
    if party in party_dict:
        return party_dict[party]
    else:
        return 5
    
##
train_data['party_id']=train_data['Party'].apply(map_political_party)
test_data['party_id']=test_data['Party'].apply(map_political_party)
val_data['party_id']=val_data['Party'].apply(map_political_party)
# Out:
# C:\Users\jshayi2\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# C:\Users\jshayi2\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
# C:\Users\jshayi2\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]

# %%
## Map states
all_states = ['Alabama','Alaska','Arizona','Arkansas','California','Colorado',
              'Connecticut','Delaware','Florida','Georgia','Hawaii','Idaho', 
              'Illinois','Indiana','Iowa','Kansas','Kentucky','Louisiana',
              'Maine' 'Maryland','Massachusetts','Michigan','Minnesota',
              'Mississippi', 'Missouri','Montana','Nebraska','Nevada',
              'New Hampshire','New Jersey','New Mexico','New York',
              'North Carolina','North Dakota','Ohio',    
              'Oklahoma','Oregon','Pennsylvania','Rhode Island',
              'South  Carolina','South Dakota','Tennessee','Texas','Utah',
              'Vermont','Virginia','Washington','West Virginia',
              'Wisconsin','Wyoming']


states_dict = {'wyoming': 48, 'colorado': 5, 'washington': 45, 'hawaii': 10, 
               'tennessee': 40, 'wisconsin': 47, 'nevada': 26, 'north dakota': 32, 
               'mississippi': 22, 'south dakota': 39, 'new jersey': 28, 'oklahoma': 34, 
               'delaware': 7, 'minnesota': 21, 'north carolina': 31, 'illinois': 12, 
               'new york': 30, 'arkansas': 3, 'west virginia': 46, 'indiana': 13, 
               'louisiana': 17, 'idaho': 11, 'south  carolina': 38, 'arizona': 2, 
               'iowa': 14, 'mainemaryland': 18, 'michigan': 20, 'kansas': 15, 
               'utah': 42, 'virginia': 44, 'oregon': 35, 'connecticut': 6, 'montana': 24, 
               'california': 4, 'massachusetts': 19, 'rhode island': 37, 'vermont': 43, 
               'georgia': 9, 'pennsylvania': 36, 'florida': 8, 'alaska': 1, 'kentucky': 16,
               'nebraska': 25, 'new hampshire': 27, 'texas': 41, 'missouri': 23, 'ohio': 33,
               'alabama': 0, 'new mexico': 29, 'rest':50}


def state_projection(state):
    if isinstance(state, str):
        state=state.lower()
        if state in states_dict:
            return states_dict[state]
        else:
            if 'washington' in state:
                return states_dict['washington']
            else:
                return 50
    else:
        return 50
    
## state mapping output:
train_data['state_id']=train_data['State Info'].apply(state_projection)
test_data['state_id']=test_data['State Info'].apply(state_projection)
val_data['state_id']=val_data['State Info'].apply(state_projection)
# Out:
# C:\Users\jshayi2\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\jshayi2\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\jshayi2\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
## map subject
subject_list = ['health','tax','immigration','election','education',
    'candidates-biography','economy','gun','jobs','federal-budget','energy','abortion','foreign-policy']

subject_dict = {'health':0,'tax':1,'immigration':2,'election':3,'education':4,
                'candidates-biography':5,'economy':6,'gun':7,'jobs':8,'federal-budget':9,
                'energy':10,'abortion':11,'foreign-policy':12, 'others':13}

## mapping subject
def subject_projection(subject):
    if isinstance(subject, str):
        subject=subject.lower()
        matched_subject=[subj for subj in subject_list if subj in subject]
        
        if len(matched_subject)>0:
            return subject_dict[matched_subject[0]]
        else:
            return 13
    else:
        return 13
    
##
train_data['subject_id']=train_data['Subject'].apply(subject_projection)
test_data['subject_id']=test_data['Subject'].apply(subject_projection)
val_data['subject_id']=val_data['Subject'].apply(subject_projection)

# %%
## Context mapping
Context_list = ['news release','interview','tv','radio',
                'campaign','news conference','press conference','press release',
                'tweet','facebook','email']

Context_dict = {'news release':0,'interview':1,'tv':2,'radio':3,
                'campaign':4,'news conference':5,'press conference':6,'press release':7,
                'tweet':8,'facebook':9,'email':10, 'others':11}

def Context_projection(context):
    if isinstance(context, str):
        context=context.lower()
        matched_context=[cntx for cntx in Context_list if cntx in context]
        if len(matched_context)>0:
            return Context_dict[matched_context[0]]
        else:
            return 11
    else:
        return 11
    
## context projection output
train_data['context_id']=train_data['Context'].apply(Context_projection)
test_data['context_id']=test_data['Context'].apply(Context_projection)
val_data['context_id']=val_data['Context'].apply(Context_projection)

# %%
### tokenize fake news statement and build vocabulary
vocab_dict={}

tokenizer = Tokenizer(num_words=20000)
tokenizer.fit_on_texts(train_data['Statement'])
vocab_dict=tokenizer.word_index
cPickle.dump(tokenizer.word_index, open("vocab.p","wb"))
print("vocab dictionary is created")
print("saved vocan dictionary to pickle file")
# Out:
# vocab dictionary is created
# saved vocan dictionary to pickle file

# %%
## data preprocessing

# def preprocessing_txt(dataset):
#     stop_words = set(stopwords.words('english'))
#     corpus=[]
#     for elm in range(0, len(dataset.index)):
#         res=' '.join([i for i in dataset['Statement'][elm].lower().split() if i not in stop_words])
#         res=re.sub("</?.*?>"," <> ",dataset['Statement'][elm])    # remove tags
#         res=re.sub("(\\d|\\W)+"," ",dataset['Statement'][elm])        # remove special characte
#         res=re.sub(r'@([A-Za-z0-9_]+)', "",dataset['Statement'][elm])  # remove twitter handler
#         res=re.sub('(\r)+', "", dataset['Statement'][elm])            # remove newline character
#         res=re.sub('[^\x00-\x7F]+', "", dataset['Statement'][elm])    # remove non-ascii characters
#         res=''.join(x for x in dataset['Statement'][elm] if x not in set(string.punctuation))   ## remove punctuation
#         corpus.append(res)
#     return corpus

# %%
### TODO: END

# %%
vocab_length = len(vocab_dict.keys())
hidden_size = 100 #Has to be same as EMBEDDING_DIM
lstm_size = 100
num_steps = 64
num_epochs = 30
batch_size = 64
#Hyperparams for CNN
kernel_sizes = [2,3,5,7]
filter_size = 128
#Meta data related hyper params
num_party = 6
num_state = 51
num_context = 12
num_job = 11
num_sub = 14
num_speaker = 21
embedding_dims=300
max_features = len(tokenizer.word_index)+1

# %%
### create embedding layer
num_words=len(vocab_dict)+1

def loadGloveModel(gloveFile):
    print("Loading Glove Model")
    embeddings_index = {}
    f = open(gloveFile, encoding='utf8')
    for line in f:
        values = line.split()
        word = ''.join(values[:-300])
        coefs = np.asarray(values[-300:], dtype='float32')
        embeddings_index[word] = coefs
    f.close()
    return embeddings_index

glove_model = loadGloveModel('glove.6B.300d.txt')

def build_glove_embedding_layers():
    embed_matrix=np.zeros((max_features, embedding_dims))
    for word, indx in tokenizer.word_index.items():
        if indx >= max_features:
            continue
        if word in glove_model:
            embed_vec=glove_model[word]
            if embed_vec is not None:
                embed_matrix[indx]=embed_vec
    return embed_matrix

embedding_weights=build_glove_embedding_layers()
# Out:
# Loading Glove Model

# %%
### data preprocessing
def preprocessing_txt_keras(statement):
    txt=text_to_word_sequence(statement)
    val=[0]*20
    val=[vocab_dict[t] for t in txt if t in vocab_dict]   ##replace unknown words with zero index
    return val

# %%
## training instances list
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
import string
stop = set(stopwords.words('english'))

### remove stopwords fitst
train_data['Statement'] = list(map(' '.join, train_data['Statement'].apply(lambda x: [item for item in x.lower().split() if item not in stop])))
test_data['Statement'] = list(map(' '.join, test_data['Statement'].apply(lambda x: [item for item in x.lower().split() if item not in stop])))
val_data['Statement'] = list(map(' '.join, val_data['Statement'].apply(lambda x: [item for item in x.lower().split() if item not in stop])))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\jshayi2\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.

# %%
train_data['word_id']=train_data['Statement'].apply(preprocessing_txt_keras)
test_data['word_id']=test_data['Statement'].apply(preprocessing_txt_keras)
val_data['word_id']=val_data['Statement'].apply(preprocessing_txt_keras)

x_train=train_data['word_id']
x_test=test_data['word_id']
x_val=val_data['word_id']

y_train=train_data['multi_label']
y_val=val_data['multi_label']

##
x_train=sequence.pad_sequences(x_train, maxlen=num_steps, padding='post', truncating='post')
y_train=to_categorical(y_train, num_classes=6)
x_val=sequence.pad_sequences(x_val, maxlen=num_steps, padding='post', truncating='post')
y_val=to_categorical(y_val, num_classes=6)
x_test=sequence.pad_sequences(x_test, maxlen=num_steps, padding='post', truncating='post')

## meta data preparation
tr_party=to_categorical(train_data['party_id'], num_classes=num_party)
tr_state=to_categorical(train_data['state_id'], num_classes=num_state)
tr_cont=to_categorical(train_data['context_id'], num_classes=num_context)
tr_job=to_categorical(train_data['job_id'], num_classes=num_job)
tr_subj=to_categorical(train_data['subject_id'], num_classes=num_sub)
# tr_speaker=to_categorical(train_data['speaker_id'], num_classes=num_speaker)

# ## put all metadata of train data together in one stack
# x_train_metadata=np.hstack(tr_party, tr_state, tr_job, tr_subj, tr_speaker, tr_cont)
x_train_metadata=np.hstack((tr_party, tr_state, tr_cont,tr_job, tr_subj))


# #********************************************************************************#
val_party=to_categorical(val_data['party_id'], num_classes=num_party)
val_state=to_categorical(val_data['state_id'], num_classes=num_state)
val_cont=to_categorical(val_data['context_id'], num_classes=num_context)
val_job=to_categorical(val_data['job_id'], num_classes=num_job)
val_subj=to_categorical(val_data['subject_id'], num_classes=num_sub)
# val_speaker=to_categorical(val_data['speaker_id'], num_classes=num_speaker)


# ## put all metadata of train data together in one stack
# x_val_metadata=np.hstack(val_party, val_state, val_job, val_subj, val_speaker, val_cont)
x_val_metadata=np.hstack((val_party, val_state, val_cont,val_job, val_subj, ))

# #********************************************************************************#
te_party=to_categorical(test_data['party_id'], num_classes=num_party)
te_state=to_categorical(test_data['state_id'], num_classes=num_state)
te_cont=to_categorical(test_data['context_id'], num_classes=num_context)
te_job=to_categorical(test_data['job_id'], num_classes=num_job)
te_subj=to_categorical(test_data['subject_id'], num_classes=num_sub)
# te_speaker=to_categorical(test_data['speaker_id'], num_classes=num_speaker)

# ## put all metadata of train data together in one stack
x_test_metadata=np.hstack((te_party, te_state, te_cont,te_job, te_subj))

# %% [markdown]
# ### Define CNN model

# %%
### to initialize model weight
np.random.seed(42)
import tensorflow as tf
tf.set_random_seed(42)

# %%
kernel_arr = []
statement_input = Input(shape=(num_steps,), dtype='int32', name='main_input')
embed_sequences = Embedding(vocab_length+1,embedding_dims,weights=[embedding_weights],input_length=num_steps,trainable=False)(statement_input) #Preloaded glove embeddings
# x = Embedding(output_dim=hidden_size, input_dim=vocab_length+1, input_length=num_steps)(statement_input) #Train embeddings from scratch

for kernel in kernel_sizes:
    x_1 = Conv1D(filters=filter_size,kernel_size=kernel, 
                 padding="same", activation="relu", strides=1)(embed_sequences)
    x_1 = MaxPool1D(3)(x_1)
    x_flat = Flatten()(x_1)
    x_drop = Dropout(0.7)(x_flat)
    kernel_arr.append(x_drop)

conv_in = keras.layers.concatenate(kernel_arr)
conv_in = Dropout(0.85)(conv_in)
conv_in = Dense(128, activation='relu')(conv_in)

#Meta input
meta_input = Input(shape=(x_train_metadata.shape[1],), name='aux_input')
x_drop = Dropout(0.7)(meta_input)
x_meta = Dense(100, activation='relu')(x_drop)
x = keras.layers.concatenate([conv_in, x_meta])

main_output = Dense(6, activation='softmax', name='main_output')(x)
model = Model(inputs=[statement_input, meta_input], outputs=[main_output])

#************************************************************************#
adam = Adam(lr=1e-4, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.2)
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(optimizer=sgd,
              loss='categorical_crossentropy',
              metrics=['categorical_accuracy'])

model.summary()

tb = TensorBoard()
csv_logger = keras.callbacks.CSVLogger('training.log')
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=2)
filepath= "weights.best.hdf5"
checkpoint = keras.callbacks.ModelCheckpoint(filepath, 
                                             monitor='val_categorical_accuracy', 
                                             verbose=1, save_best_only=True, mode='max')

history= model.fit({'main_input': x_train, 'aux_input': x_train_metadata},
                   {'main_output': y_train},epochs=30, batch_size=100,
                   validation_data=({'main_input': x_val, 'aux_input': x_val_metadata},{'main_output': y_val}),
                  callbacks=[tb,csv_logger,checkpoint, es])
# Out:
# WARNING:tensorflow:From C:\Users\jshayi2\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\Users\jshayi2\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# main_input (InputLayer)         (None, 64)           0
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, 64, 300)      3722700     main_input[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 64, 128)      76928       embedding_1[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 64, 128)      115328      embedding_1[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 64, 128)      192128      embedding_1[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 64, 128)      268928      embedding_1[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_1 (MaxPooling1D)  (None, 21, 128)      0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_2 (MaxPooling1D)  (None, 21, 128)      0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_3 (MaxPooling1D)  (None, 21, 128)      0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_4 (MaxPooling1D)  (None, 21, 128)      0           conv1d_4[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 2688)         0           max_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 2688)         0           max_pooling1d_2[0][0]
# __________________________________________________________________________________________________
# flatten_3 (Flatten)             (None, 2688)         0           max_pooling1d_3[0][0]
# __________________________________________________________________________________________________
# flatten_4 (Flatten)             (None, 2688)         0           max_pooling1d_4[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 2688)         0           flatten_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 2688)         0           flatten_2[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 2688)         0           flatten_3[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 2688)         0           flatten_4[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 10752)        0           dropout_1[0][0]
#                                                                  dropout_2[0][0]
#                                                                  dropout_3[0][0]
#                                                                  dropout_4[0][0]
# __________________________________________________________________________________________________
# aux_input (InputLayer)          (None, 94)           0
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 10752)        0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 94)           0           aux_input[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          1376384     dropout_5[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 100)          9500        dropout_6[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 228)          0           dense_1[0][0]
#                                                                  dense_2[0][0]
# __________________________________________________________________________________________________
# main_output (Dense)             (None, 6)            1374        concatenate_2[0][0]
# ==================================================================================================
# Total params: 5,763,270
# Trainable params: 2,040,570
# Non-trainable params: 3,722,700
# __________________________________________________________________________________________________
# WARNING:tensorflow:From C:\Users\jshayi2\AppData\Local\Continuum\anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 10240 samples, validate on 1284 samples
# Epoch 1/30
# 10240/10240 [==============================] - 42s 4ms/step - loss: 1.8466 - categorical_accuracy: 0.1957 - val_loss: 1.7739 - val_categorical_accuracy: 0.2025
#
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.20249, saving model to weights.best.hdf5
# Epoch 2/30
# 10240/10240 [==============================] - 39s 4ms/step - loss: 1.7659 - categorical_accuracy: 0.2101 - val_loss: 1.7676 - val_categorical_accuracy: 0.2095
#
# Epoch 00002: val_categorical_accuracy improved from 0.20249 to 0.20950, saving model to weights.best.hdf5
# Epoch 3/30
# 10240/10240 [==============================] - 39s 4ms/step - loss: 1.7552 - categorical_accuracy: 0.2135 - val_loss: 1.7530 - val_categorical_accuracy: 0.2305
#
# Epoch 00003: val_categorical_accuracy improved from 0.20950 to 0.23053, saving model to weights.best.hdf5
# Epoch 4/30
# 10240/10240 [==============================] - 39s 4ms/step - loss: 1.7484 - categorical_accuracy: 0.2222 - val_loss: 1.7462 - val_categorical_accuracy: 0.2298
#
# Epoch 00004: val_categorical_accuracy did not improve from 0.23053
# Epoch 5/30
# 10240/10240 [==============================] - 39s 4ms/step - loss: 1.7433 - categorical_accuracy: 0.2209 - val_loss: 1.7506 - val_categorical_accuracy: 0.2227
#
# Epoch 00005: val_categorical_accuracy did not improve from 0.23053
# Epoch 6/30
# 10240/10240 [==============================] - 39s 4ms/step - loss: 1.7414 - categorical_accuracy: 0.2250 - val_loss: 1.7441 - val_categorical_accuracy: 0.2375
#
# Epoch 00006: val_categorical_accuracy improved from 0.23053 to 0.23754, saving model to weights.best.hdf5
# Epoch 7/30
# 10240/10240 [==============================] - 39s 4ms/step - loss: 1.7384 - categorical_accuracy: 0.2325 - val_loss: 1.7415 - val_categorical_accuracy: 0.2266
#
# Epoch 00007: val_categorical_accuracy did not improve from 0.23754
# Epoch 8/30
# 10240/10240 [==============================] - 39s 4ms/step - loss: 1.7341 - categorical_accuracy: 0.2344 - val_loss: 1.7402 - val_categorical_accuracy: 0.2329
#
# Epoch 00008: val_categorical_accuracy did not improve from 0.23754
# Epoch 9/30
# 10240/10240 [==============================] - 41s 4ms/step - loss: 1.7316 - categorical_accuracy: 0.2362 - val_loss: 1.7351 - val_categorical_accuracy: 0.2360
#
# Epoch 00009: val_categorical_accuracy did not improve from 0.23754
# Epoch 10/30
# 10240/10240 [==============================] - 39s 4ms/step - loss: 1.7292 - categorical_accuracy: 0.2360 - val_loss: 1.7359 - val_categorical_accuracy: 0.2305
#
# Epoch 00010: val_categorical_accuracy did not improve from 0.23754
# Epoch 11/30
# 10240/10240 [==============================] - 39s 4ms/step - loss: 1.7289 - categorical_accuracy: 0.2382 - val_loss: 1.7286 - val_categorical_accuracy: 0.2368
#
# Epoch 00011: val_categorical_accuracy did not improve from 0.23754
# Epoch 12/30
# 10240/10240 [==============================] - 45s 4ms/step - loss: 1.7239 - categorical_accuracy: 0.2433 - val_loss: 1.7274 - val_categorical_accuracy: 0.2461
#
# Epoch 00012: val_categorical_accuracy improved from 0.23754 to 0.24611, saving model to weights.best.hdf5
# Epoch 13/30
# 10240/10240 [==============================] - 42s 4ms/step - loss: 1.7234 - categorical_accuracy: 0.2441 - val_loss: 1.7264 - val_categorical_accuracy: 0.2438
#
# Epoch 00013: val_categorical_accuracy did not improve from 0.24611
# Epoch 14/30
# 10240/10240 [==============================] - 45s 4ms/step - loss: 1.7181 - categorical_accuracy: 0.2479 - val_loss: 1.7241 - val_categorical_accuracy: 0.2500
#
# Epoch 00014: val_categorical_accuracy improved from 0.24611 to 0.25000, saving model to weights.best.hdf5
# Epoch 15/30
# 10240/10240 [==============================] - 47s 5ms/step - loss: 1.7194 - categorical_accuracy: 0.2486 - val_loss: 1.7224 - val_categorical_accuracy: 0.2523
#
# Epoch 00015: val_categorical_accuracy improved from 0.25000 to 0.25234, saving model to weights.best.hdf5
# Epoch 16/30
# 10240/10240 [==============================] - 41s 4ms/step - loss: 1.7179 - categorical_accuracy: 0.2513 - val_loss: 1.7237 - val_categorical_accuracy: 0.2469
#
# Epoch 00016: val_categorical_accuracy did not improve from 0.25234
# Epoch 17/30
# 10240/10240 [==============================] - 41s 4ms/step - loss: 1.7146 - categorical_accuracy: 0.2512 - val_loss: 1.7238 - val_categorical_accuracy: 0.2469
#
# Epoch 00017: val_categorical_accuracy did not improve from 0.25234
# Epoch 00017: early stopping

# %%
accu_curve=plt.figure()
plt.plot(history.history['categorical_accuracy'],'r',linewidth=3.0)
plt.plot(history.history['val_categorical_accuracy'],'b',linewidth=3.0)
plt.legend(['Training Accuracy', 'Validation Accuracy'],fontsize=12)
plt.xlabel('Epochs ',fontsize=12)
plt.ylabel('Accuracy',fontsize=12)
plt.title('Accuracy Curves : CNN',fontsize=12)
accu_curve.savefig('accuracy_cnn_improved_v1.2.png')
plt.show()
##^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^##
loss_curve = plt.figure()
plt.plot(history.history['loss'],'r',linewidth=3.0)
plt.plot(history.history['val_loss'],'b',linewidth=3.0)
plt.legend(['Training loss', 'Validation Loss'],fontsize=12)
plt.xlabel('Epochs ',fontsize=12)
plt.ylabel('Loss',fontsize=12)
plt.title('Loss Curves :CNN',fontsize=12)
loss_curve.savefig('loss_cnn_improved_v1.2.png')
loss_curve.show()

# %% [markdown]
# ## Use multi-convolutional CNN model for fake news classification

# %% [markdown]
# Let's do small modification on above CNN model, in this notebook I introduce multi convolutional CNN model for fake news classification. let's see how it works and see where is significancy.

# %%
statement_input = Input(shape=(num_steps,), dtype='int64', name='main_input')
embed_sequence = Embedding(vocab_length+1,embedding_dims,weights=[embedding_weights],input_length=num_steps,trainable=False)(statement_input) #Preloaded glove embeddings

## add multi convolutional layer
l_conv1 = Conv1D(128,3,activation="relu", padding="same", strides=1)(embed_sequence)
l_pool1 = MaxPooling1D(3)(l_conv1)
l_conv2 = Conv1D(128, 3, activation="relu")(l_pool1)
l_pool2 = MaxPooling1D(3)(l_conv2)
# l_conv3 = Conv1D(128,3,activation="relu")(l_pool2)
# l_pool3 = MaxPool1D(3)(l_conv3)
l_flat = Flatten()(l_pool2)
conv_in = Dropout(0.9)(l_flat)
conv_in = Dense(hidden_size, activation='relu')(conv_in)

#Meta input
meta_input = Input(shape=(x_train_metadata.shape[1],), name='aux_input')
x_meta = Dense(64, activation='relu')(meta_input)
x = keras.layers.concatenate([conv_in, x_meta])

main_output = Dense(6, activation='softmax', name='main_output')(x)
model_multi = Model(inputs=[statement_input, meta_input], outputs=[main_output])

#************************************************************************#
adam = Adam(lr=1e-4, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.2)
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model_multi.compile(optimizer=sgd,
                    loss='categorical_crossentropy',
                    metrics=['categorical_accuracy'])

model_multi.summary()

tb = TensorBoard()
csv_logger = keras.callbacks.CSVLogger('training.log')
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=2)
filepath= "weights.best.hdf5"
checkpoint = keras.callbacks.ModelCheckpoint(filepath, 
                                             monitor='val_categorical_accuracy', 
                                             verbose=1, save_best_only=True, mode='max')

history22= model_multi.fit({'main_input': x_train, 'aux_input': x_train_metadata},
                           {'main_output': y_train},epochs=15, batch_size=100,
                           validation_data=({'main_input': x_val, 'aux_input': x_val_metadata},{'main_output': y_val}),
                           callbacks=[tb,csv_logger,checkpoint, es])
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# main_input (InputLayer)         (None, 64)           0
# __________________________________________________________________________________________________
# embedding_24 (Embedding)        (None, 64, 300)      3722700     main_input[0][0]
# __________________________________________________________________________________________________
# conv1d_69 (Conv1D)              (None, 64, 128)      115328      embedding_24[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_45 (MaxPooling1D) (None, 21, 128)      0           conv1d_69[0][0]
# __________________________________________________________________________________________________
# conv1d_70 (Conv1D)              (None, 19, 128)      49280       max_pooling1d_45[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_46 (MaxPooling1D) (None, 6, 128)       0           conv1d_70[0][0]
# __________________________________________________________________________________________________
# flatten_13 (Flatten)            (None, 768)          0           max_pooling1d_46[0][0]
# __________________________________________________________________________________________________
# dropout_34 (Dropout)            (None, 768)          0           flatten_13[0][0]
# __________________________________________________________________________________________________
# aux_input (InputLayer)          (None, 94)           0
# __________________________________________________________________________________________________
# dense_33 (Dense)                (None, 100)          76900       dropout_34[0][0]
# __________________________________________________________________________________________________
# dense_34 (Dense)                (None, 64)           6080        aux_input[0][0]
# __________________________________________________________________________________________________
# concatenate_22 (Concatenate)    (None, 164)          0           dense_33[0][0]
#                                                                  dense_34[0][0]
# __________________________________________________________________________________________________
# main_output (Dense)             (None, 6)            990         concatenate_22[0][0]
# ==================================================================================================
# Total params: 3,971,278
# Trainable params: 248,578
# Non-trainable params: 3,722,700
# __________________________________________________________________________________________________
# Train on 10240 samples, validate on 1284 samples
# Epoch 1/15
# 10240/10240 [==============================] - 9s 876us/step - loss: 1.7832 - categorical_accuracy: 0.2000 - val_loss: 1.7447 - val_categorical_accuracy: 0.2134
#
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.21340, saving model to weights.best.hdf5
# Epoch 2/15
# 10240/10240 [==============================] - 9s 831us/step - loss: 1.7446 - categorical_accuracy: 0.2233 - val_loss: 1.7362 - val_categorical_accuracy: 0.2321
#
# Epoch 00002: val_categorical_accuracy improved from 0.21340 to 0.23209, saving model to weights.best.hdf5
# Epoch 3/15
# 10240/10240 [==============================] - 8s 801us/step - loss: 1.7299 - categorical_accuracy: 0.2323 - val_loss: 1.7225 - val_categorical_accuracy: 0.2336
#
# Epoch 00003: val_categorical_accuracy improved from 0.23209 to 0.23364, saving model to weights.best.hdf5
# Epoch 4/15
# 10240/10240 [==============================] - 8s 799us/step - loss: 1.7223 - categorical_accuracy: 0.2406 - val_loss: 1.7181 - val_categorical_accuracy: 0.2391
#
# Epoch 00004: val_categorical_accuracy improved from 0.23364 to 0.23910, saving model to weights.best.hdf5
# Epoch 5/15
# 10240/10240 [==============================] - 8s 798us/step - loss: 1.7159 - categorical_accuracy: 0.2500 - val_loss: 1.7103 - val_categorical_accuracy: 0.2438
#
# Epoch 00005: val_categorical_accuracy improved from 0.23910 to 0.24377, saving model to weights.best.hdf5
# Epoch 6/15
# 10240/10240 [==============================] - 8s 805us/step - loss: 1.7099 - categorical_accuracy: 0.2504 - val_loss: 1.7084 - val_categorical_accuracy: 0.2399
#
# Epoch 00006: val_categorical_accuracy did not improve from 0.24377
# Epoch 7/15
# 10240/10240 [==============================] - 8s 803us/step - loss: 1.7048 - categorical_accuracy: 0.2622 - val_loss: 1.7012 - val_categorical_accuracy: 0.2453
#
# Epoch 00007: val_categorical_accuracy improved from 0.24377 to 0.24533, saving model to weights.best.hdf5
# Epoch 8/15
# 10240/10240 [==============================] - 8s 804us/step - loss: 1.6955 - categorical_accuracy: 0.2663 - val_loss: 1.6947 - val_categorical_accuracy: 0.2477
#
# Epoch 00008: val_categorical_accuracy improved from 0.24533 to 0.24766, saving model to weights.best.hdf5
# Epoch 9/15
# 10240/10240 [==============================] - 8s 801us/step - loss: 1.6965 - categorical_accuracy: 0.2625 - val_loss: 1.6975 - val_categorical_accuracy: 0.2547
#
# Epoch 00009: val_categorical_accuracy improved from 0.24766 to 0.25467, saving model to weights.best.hdf5
# Epoch 10/15
# 10240/10240 [==============================] - 8s 807us/step - loss: 1.6897 - categorical_accuracy: 0.2712 - val_loss: 1.6898 - val_categorical_accuracy: 0.2617
#
# Epoch 00010: val_categorical_accuracy improved from 0.25467 to 0.26168, saving model to weights.best.hdf5
# Epoch 11/15
# 10240/10240 [==============================] - 8s 802us/step - loss: 1.6811 - categorical_accuracy: 0.2759 - val_loss: 1.6856 - val_categorical_accuracy: 0.2734
#
# Epoch 00011: val_categorical_accuracy improved from 0.26168 to 0.27336, saving model to weights.best.hdf5
# Epoch 12/15
# 10240/10240 [==============================] - 8s 808us/step - loss: 1.6812 - categorical_accuracy: 0.2768 - val_loss: 1.6877 - val_categorical_accuracy: 0.2664
#
# Epoch 00012: val_categorical_accuracy did not improve from 0.27336
# Epoch 13/15
# 10240/10240 [==============================] - 8s 819us/step - loss: 1.6733 - categorical_accuracy: 0.2794 - val_loss: 1.6830 - val_categorical_accuracy: 0.2749
#
# Epoch 00013: val_categorical_accuracy improved from 0.27336 to 0.27492, saving model to weights.best.hdf5
# Epoch 14/15
# 10240/10240 [==============================] - 8s 808us/step - loss: 1.6660 - categorical_accuracy: 0.2853 - val_loss: 1.6810 - val_categorical_accuracy: 0.2741
#
# Epoch 00014: val_categorical_accuracy did not improve from 0.27492
# Epoch 15/15
# 10240/10240 [==============================] - 8s 821us/step - loss: 1.6634 - categorical_accuracy: 0.2872 - val_loss: 1.6881 - val_categorical_accuracy: 0.2648
#
# Epoch 00015: val_categorical_accuracy did not improve from 0.27492

# %%
## to see performance difference
accu_curve=plt.figure()
plt.plot(history22.history['categorical_accuracy'],'r',linewidth=3.0)
plt.plot(history22.history['val_categorical_accuracy'],'b',linewidth=3.0)
plt.legend(['Training Accuracy', 'Validation Accuracy'],fontsize=12)
plt.xlabel('Epochs ',fontsize=12)
plt.ylabel('Accuracy',fontsize=12)
plt.title('Accuracy Curves : CNN_multi',fontsize=12)
accu_curve.savefig('accuracy_multi_conv_cnn.png')
plt.show()
##^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^##
loss_curve = plt.figure()
plt.plot(history22.history['loss'],'r',linewidth=3.0)
plt.plot(history22.history['val_loss'],'b',linewidth=3.0)
plt.legend(['Training loss', 'Validation Loss'],fontsize=12)
plt.xlabel('Epochs ',fontsize=12)
plt.ylabel('Loss',fontsize=12)
plt.title('Loss Curves :CNN Multi',fontsize=12)
loss_curve.savefig('loss_multi_conv_cnn.png')
loss_curve.show()

# %% [markdown]
# #### if we run the model multiple times (Experiment)

# %%
kernel_arr = []
statement_input = Input(shape=(num_steps,), dtype='int32', name='main_input')
embed_sequences = Embedding(vocab_length+1,embedding_dims,weights=[embedding_weights],input_length=num_steps,trainable=False)(statement_input) #Preloaded glove embeddings
# x = Embedding(output_dim=hidden_size, input_dim=vocab_length+1, input_length=num_steps)(statement_input) #Train embeddings from scratch

# for kernel in kernel_sizes:
#     x_1 = Conv1D(filters=filter_size,kernel_size=kernel, 
#                  padding="same", activation="relu", strides=1)(embed_sequences)
#     x_1 = MaxPool1D(3)(x_1)
#     x_flat = Flatten()(x_1)
#     x_drop = Dropout(0.6)(x_flat)
#     kernel_arr.append(x_drop)

# conv_in = keras.layers.concatenate(kernel_arr)
# conv_in = Dropout(0.7)(conv_in)
# conv_in = Dense(128, activation='relu')(conv_in)

# #Meta input
# meta_input = Input(shape=(x_train_metadata.shape[1],), name='aux_input')
# x_drop = Dropout(0.7)(meta_input)
# x_meta = Dense(100, activation='relu')(x_drop)
# x = keras.layers.concatenate([conv_in, x_meta])

# main_output = Dense(6, activation='softmax', name='main_output')(x)
# model = Model(inputs=[statement_input, meta_input], outputs=[main_output])

## add multi convolutional layer
l_conv1 = Conv1D(128,3,activation="relu", padding="same", strides=1)(embed_sequences)
l_pool1 = MaxPooling1D(3)(l_conv1)
l_conv2 = Conv1D(128, 3, activation="relu")(l_pool1)
l_pool2 = MaxPooling1D(3)(l_conv2)
# l_conv3 = Conv1D(128,3,activation="relu")(l_pool2)
# l_pool3 = MaxPool1D(3)(l_conv3)
l_flat = Flatten()(l_pool2)
conv_in = Dropout(0.9)(l_flat)
conv_in = Dense(hidden_size, activation='relu')(conv_in)

#Meta input
meta_input = Input(shape=(x_train_metadata.shape[1],), name='aux_input')
x_drop = Dropout(0.8)(meta_input)
x_meta = Dense(64, activation='relu')(x_drop)
x = keras.layers.concatenate([conv_in, x_meta])

main_output = Dense(6, activation='softmax', name='main_output')(x)

sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)

####
runs=5
histArr = []

for i in range(runs):
    print('Running iteration %i/%i' % (i+1, runs))
    model_multirun = Model(inputs=[statement_input, meta_input], outputs=[main_output])
    model_multirun.compile(optimizer=sgd,
                          loss='categorical_crossentropy',
                          metrics=['categorical_accuracy'])
    
    ####
    tb = TensorBoard()
    csv_logger = keras.callbacks.CSVLogger('training.log')
    #es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=2)
    #filepath= "weights.best.hdf5"
    # checkpoint = keras.callbacks.ModelCheckpoint(filepath, 
    #                                              monitor='val_categorical_accuracy', 
    #                                              verbose=1, save_best_only=True, mode='max')

    history22= model_multirun.fit({'main_input': x_train, 'aux_input': x_train_metadata},
                                  {'main_output': y_train},epochs=30, batch_size=100, verbose=1,
                                  validation_data=({'main_input': x_val, 'aux_input': x_val_metadata},{'main_output': y_val}),
                                  callbacks=[keras.callbacks.ModelCheckpoint('model-%i.h5'%(i+1), 
                                                                              monitor='val_categorical_accuracy', verbose=1, 
                                                                              save_best_only=True, mode='max'), tb, csv_logger])
                       #callbacks=[tb,csv_logger,checkpoint, es])
    print()
    histArr.append(history22.history)
# Out:
# Running iteration 1/5
# Train on 10240 samples, validate on 1284 samples
# Epoch 1/30
# 10240/10240 [==============================] - 9s 907us/step - loss: 1.7968 - categorical_accuracy: 0.1988 - val_loss: 1.7593 - val_categorical_accuracy: 0.2103
#
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.21028, saving model to model-1.h5
# Epoch 2/30
# 10240/10240 [==============================] - 8s 775us/step - loss: 1.7636 - categorical_accuracy: 0.2092 - val_loss: 1.7505 - val_categorical_accuracy: 0.2298
#
# Epoch 00002: val_categorical_accuracy improved from 0.21028 to 0.22975, saving model to model-1.h5
# Epoch 3/30
# 10240/10240 [==============================] - 8s 764us/step - loss: 1.7552 - categorical_accuracy: 0.2198 - val_loss: 1.7463 - val_categorical_accuracy: 0.2453
#
# Epoch 00003: val_categorical_accuracy improved from 0.22975 to 0.24533, saving model to model-1.h5
# Epoch 4/30
# 10240/10240 [==============================] - 8s 780us/step - loss: 1.7527 - categorical_accuracy: 0.2149 - val_loss: 1.7418 - val_categorical_accuracy: 0.2625
#
# Epoch 00004: val_categorical_accuracy improved from 0.24533 to 0.26246, saving model to model-1.h5
# Epoch 5/30
# 10240/10240 [==============================] - 8s 787us/step - loss: 1.7454 - categorical_accuracy: 0.2214 - val_loss: 1.7376 - val_categorical_accuracy: 0.2539
#
# Epoch 00005: val_categorical_accuracy did not improve from 0.26246
# Epoch 6/30
# 10240/10240 [==============================] - 8s 790us/step - loss: 1.7447 - categorical_accuracy: 0.2246 - val_loss: 1.7363 - val_categorical_accuracy: 0.2422
#
# Epoch 00006: val_categorical_accuracy did not improve from 0.26246
# Epoch 7/30
# 10240/10240 [==============================] - 8s 788us/step - loss: 1.7362 - categorical_accuracy: 0.2336 - val_loss: 1.7285 - val_categorical_accuracy: 0.2523
#
# Epoch 00007: val_categorical_accuracy did not improve from 0.26246
# Epoch 8/30
# 10240/10240 [==============================] - 8s 786us/step - loss: 1.7353 - categorical_accuracy: 0.2332 - val_loss: 1.7273 - val_categorical_accuracy: 0.2570
#
# Epoch 00008: val_categorical_accuracy did not improve from 0.26246
# Epoch 9/30
# 10240/10240 [==============================] - 8s 772us/step - loss: 1.7330 - categorical_accuracy: 0.2358 - val_loss: 1.7247 - val_categorical_accuracy: 0.2547
#
# Epoch 00009: val_categorical_accuracy did not improve from 0.26246
# Epoch 10/30
# 10240/10240 [==============================] - 8s 769us/step - loss: 1.7294 - categorical_accuracy: 0.2407 - val_loss: 1.7204 - val_categorical_accuracy: 0.2648
#
# Epoch 00010: val_categorical_accuracy improved from 0.26246 to 0.26480, saving model to model-1.h5
# Epoch 11/30
# 10240/10240 [==============================] - 8s 770us/step - loss: 1.7267 - categorical_accuracy: 0.2412 - val_loss: 1.7209 - val_categorical_accuracy: 0.2562
#
# Epoch 00011: val_categorical_accuracy did not improve from 0.26480
# Epoch 12/30
# 10240/10240 [==============================] - 8s 770us/step - loss: 1.7223 - categorical_accuracy: 0.2379 - val_loss: 1.7159 - val_categorical_accuracy: 0.2648
#
# Epoch 00012: val_categorical_accuracy improved from 0.26480 to 0.26480, saving model to model-1.h5
# Epoch 13/30
# 10240/10240 [==============================] - 8s 787us/step - loss: 1.7177 - categorical_accuracy: 0.2461 - val_loss: 1.7154 - val_categorical_accuracy: 0.2601
#
# Epoch 00013: val_categorical_accuracy did not improve from 0.26480
# Epoch 14/30
# 10240/10240 [==============================] - 8s 775us/step - loss: 1.7089 - categorical_accuracy: 0.2528 - val_loss: 1.7085 - val_categorical_accuracy: 0.2601
#
# Epoch 00014: val_categorical_accuracy did not improve from 0.26480
# Epoch 15/30
# 10240/10240 [==============================] - 8s 779us/step - loss: 1.7043 - categorical_accuracy: 0.2564 - val_loss: 1.7087 - val_categorical_accuracy: 0.2586
#
# Epoch 00015: val_categorical_accuracy did not improve from 0.26480
# Epoch 16/30
# 10240/10240 [==============================] - 8s 773us/step - loss: 1.7022 - categorical_accuracy: 0.2532 - val_loss: 1.7058 - val_categorical_accuracy: 0.2601
#
# Epoch 00016: val_categorical_accuracy did not improve from 0.26480
# Epoch 17/30
# 10240/10240 [==============================] - 9s 843us/step - loss: 1.6967 - categorical_accuracy: 0.2589 - val_loss: 1.7032 - val_categorical_accuracy: 0.2609
#
# Epoch 00017: val_categorical_accuracy did not improve from 0.26480
# Epoch 18/30
# 10240/10240 [==============================] - 9s 904us/step - loss: 1.6965 - categorical_accuracy: 0.2615 - val_loss: 1.7044 - val_categorical_accuracy: 0.2531
#
# Epoch 00018: val_categorical_accuracy did not improve from 0.26480
# Epoch 19/30
# 10240/10240 [==============================] - 9s 871us/step - loss: 1.6886 - categorical_accuracy: 0.2664 - val_loss: 1.7031 - val_categorical_accuracy: 0.2492
#
# Epoch 00019: val_categorical_accuracy did not improve from 0.26480
# Epoch 20/30
# 10240/10240 [==============================] - 9s 868us/step - loss: 1.6732 - categorical_accuracy: 0.2715 - val_loss: 1.6984 - val_categorical_accuracy: 0.2625
#
# Epoch 00020: val_categorical_accuracy did not improve from 0.26480
# Epoch 21/30
# 10240/10240 [==============================] - 9s 868us/step - loss: 1.6739 - categorical_accuracy: 0.2749 - val_loss: 1.7034 - val_categorical_accuracy: 0.2671
#
# Epoch 00021: val_categorical_accuracy improved from 0.26480 to 0.26713, saving model to model-1.h5
# Epoch 22/30
# 10240/10240 [==============================] - 9s 850us/step - loss: 1.6632 - categorical_accuracy: 0.2838 - val_loss: 1.7037 - val_categorical_accuracy: 0.2453
#
# Epoch 00022: val_categorical_accuracy did not improve from 0.26713
# Epoch 23/30
# 10240/10240 [==============================] - 9s 843us/step - loss: 1.6543 - categorical_accuracy: 0.2903 - val_loss: 1.6940 - val_categorical_accuracy: 0.2617
#
# Epoch 00023: val_categorical_accuracy did not improve from 0.26713
# Epoch 24/30
# 10240/10240 [==============================] - 9s 851us/step - loss: 1.6431 - categorical_accuracy: 0.2864 - val_loss: 1.6972 - val_categorical_accuracy: 0.2523
#
# Epoch 00024: val_categorical_accuracy did not improve from 0.26713
# Epoch 25/30
# 10240/10240 [==============================] - 9s 852us/step - loss: 1.6427 - categorical_accuracy: 0.2885 - val_loss: 1.7045 - val_categorical_accuracy: 0.2555
#
# Epoch 00025: val_categorical_accuracy did not improve from 0.26713
# Epoch 26/30
# 10240/10240 [==============================] - 9s 852us/step - loss: 1.6231 - categorical_accuracy: 0.3012 - val_loss: 1.7002 - val_categorical_accuracy: 0.2453
#
# Epoch 00026: val_categorical_accuracy did not improve from 0.26713
# Epoch 27/30
# 10240/10240 [==============================] - 9s 857us/step - loss: 1.6141 - categorical_accuracy: 0.3051 - val_loss: 1.7025 - val_categorical_accuracy: 0.2625
#
# Epoch 00027: val_categorical_accuracy did not improve from 0.26713
# Epoch 28/30
# 10240/10240 [==============================] - 8s 827us/step - loss: 1.5995 - categorical_accuracy: 0.3115 - val_loss: 1.7079 - val_categorical_accuracy: 0.2290
#
# Epoch 00028: val_categorical_accuracy did not improve from 0.26713
# Epoch 29/30
# 10240/10240 [==============================] - 8s 807us/step - loss: 1.5791 - categorical_accuracy: 0.3179 - val_loss: 1.7095 - val_categorical_accuracy: 0.2375
#
# Epoch 00029: val_categorical_accuracy did not improve from 0.26713
# Epoch 30/30
# 10240/10240 [==============================] - 8s 809us/step - loss: 1.5693 - categorical_accuracy: 0.3227 - val_loss: 1.7240 - val_categorical_accuracy: 0.2422
#
# Epoch 00030: val_categorical_accuracy did not improve from 0.26713
#
# Running iteration 2/5
# Train on 10240 samples, validate on 1284 samples
# Epoch 1/30
# 10240/10240 [==============================] - 11s 1ms/step - loss: 1.5474 - categorical_accuracy: 0.3307 - val_loss: 1.7271 - val_categorical_accuracy: 0.2375
#
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.23754, saving model to model-2.h5
# Epoch 2/30
# 10240/10240 [==============================] - 9s 866us/step - loss: 1.5252 - categorical_accuracy: 0.3363 - val_loss: 1.7282 - val_categorical_accuracy: 0.2484
#
# Epoch 00002: val_categorical_accuracy improved from 0.23754 to 0.24844, saving model to model-2.h5
# Epoch 3/30
# 10240/10240 [==============================] - 8s 824us/step - loss: 1.5196 - categorical_accuracy: 0.3409 - val_loss: 1.8849 - val_categorical_accuracy: 0.2508
#
# Epoch 00003: val_categorical_accuracy improved from 0.24844 to 0.25078, saving model to model-2.h5
# Epoch 4/30
# 10240/10240 [==============================] - 9s 860us/step - loss: 1.4933 - categorical_accuracy: 0.3551 - val_loss: 1.8026 - val_categorical_accuracy: 0.2484
#
# Epoch 00004: val_categorical_accuracy did not improve from 0.25078
# Epoch 5/30
# 10240/10240 [==============================] - 8s 811us/step - loss: 1.4706 - categorical_accuracy: 0.3627 - val_loss: 1.7753 - val_categorical_accuracy: 0.2531
#
# Epoch 00005: val_categorical_accuracy improved from 0.25078 to 0.25312, saving model to model-2.h5
# Epoch 6/30
# 10240/10240 [==============================] - 8s 818us/step - loss: 1.4624 - categorical_accuracy: 0.3656 - val_loss: 1.7771 - val_categorical_accuracy: 0.2523
#
# Epoch 00006: val_categorical_accuracy did not improve from 0.25312
# Epoch 7/30
# 10240/10240 [==============================] - 8s 822us/step - loss: 1.4299 - categorical_accuracy: 0.3809 - val_loss: 1.8294 - val_categorical_accuracy: 0.2329
#
# Epoch 00007: val_categorical_accuracy did not improve from 0.25312
# Epoch 8/30
# 10240/10240 [==============================] - 8s 821us/step - loss: 1.4069 - categorical_accuracy: 0.3897 - val_loss: 1.8385 - val_categorical_accuracy: 0.2570
#
# Epoch 00008: val_categorical_accuracy improved from 0.25312 to 0.25701, saving model to model-2.h5
# Epoch 9/30
# 10240/10240 [==============================] - 8s 803us/step - loss: 1.3753 - categorical_accuracy: 0.4065 - val_loss: 1.9740 - val_categorical_accuracy: 0.2414
#
# Epoch 00009: val_categorical_accuracy did not improve from 0.25701
# Epoch 10/30
# 10240/10240 [==============================] - 8s 801us/step - loss: 1.3625 - categorical_accuracy: 0.4015 - val_loss: 1.9762 - val_categorical_accuracy: 0.2477
#
# Epoch 00010: val_categorical_accuracy did not improve from 0.25701
# Epoch 11/30
# 10240/10240 [==============================] - 8s 817us/step - loss: 1.3419 - categorical_accuracy: 0.4157 - val_loss: 1.9437 - val_categorical_accuracy: 0.2438
#
# Epoch 00011: val_categorical_accuracy did not improve from 0.25701
# Epoch 12/30
# 10240/10240 [==============================] - 9s 835us/step - loss: 1.3272 - categorical_accuracy: 0.4113 - val_loss: 1.9476 - val_categorical_accuracy: 0.2477
#
# Epoch 00012: val_categorical_accuracy did not improve from 0.25701
# Epoch 13/30
# 10240/10240 [==============================] - 9s 834us/step - loss: 1.2906 - categorical_accuracy: 0.4342 - val_loss: 2.0286 - val_categorical_accuracy: 0.2469
#
# Epoch 00013: val_categorical_accuracy did not improve from 0.25701
# Epoch 14/30
# 10240/10240 [==============================] - 9s 840us/step - loss: 1.2802 - categorical_accuracy: 0.4369 - val_loss: 2.0877 - val_categorical_accuracy: 0.2430
#
# Epoch 00014: val_categorical_accuracy did not improve from 0.25701
# Epoch 15/30
# 10240/10240 [==============================] - 8s 825us/step - loss: 1.2640 - categorical_accuracy: 0.4478 - val_loss: 2.3786 - val_categorical_accuracy: 0.2235
#
# Epoch 00015: val_categorical_accuracy did not improve from 0.25701
# Epoch 16/30
# 10240/10240 [==============================] - 8s 821us/step - loss: 1.2322 - categorical_accuracy: 0.4534 - val_loss: 2.2564 - val_categorical_accuracy: 0.2414
#
# Epoch 00016: val_categorical_accuracy did not improve from 0.25701
# Epoch 17/30
# 10240/10240 [==============================] - 8s 824us/step - loss: 1.2211 - categorical_accuracy: 0.4677 - val_loss: 2.2802 - val_categorical_accuracy: 0.2593
#
# Epoch 00017: val_categorical_accuracy improved from 0.25701 to 0.25935, saving model to model-2.h5
# Epoch 18/30
# 10240/10240 [==============================] - 8s 827us/step - loss: 1.1905 - categorical_accuracy: 0.4722 - val_loss: 2.2707 - val_categorical_accuracy: 0.2407
#
# Epoch 00018: val_categorical_accuracy did not improve from 0.25935
# Epoch 19/30
# 10240/10240 [==============================] - 8s 824us/step - loss: 1.1817 - categorical_accuracy: 0.4823 - val_loss: 2.8143 - val_categorical_accuracy: 0.2313
#
# Epoch 00019: val_categorical_accuracy did not improve from 0.25935
# Epoch 20/30
# 10240/10240 [==============================] - 8s 826us/step - loss: 1.1674 - categorical_accuracy: 0.4873 - val_loss: 2.3084 - val_categorical_accuracy: 0.2461
#
# Epoch 00020: val_categorical_accuracy did not improve from 0.25935
# Epoch 21/30
# 10240/10240 [==============================] - 9s 832us/step - loss: 1.1319 - categorical_accuracy: 0.5050 - val_loss: 2.3772 - val_categorical_accuracy: 0.2414
#
# Epoch 00021: val_categorical_accuracy did not improve from 0.25935
# Epoch 22/30
# 10240/10240 [==============================] - 9s 842us/step - loss: 1.1237 - categorical_accuracy: 0.5066 - val_loss: 2.3833 - val_categorical_accuracy: 0.2492
#
# Epoch 00022: val_categorical_accuracy did not improve from 0.25935
# Epoch 23/30
# 10240/10240 [==============================] - 9s 832us/step - loss: 1.1223 - categorical_accuracy: 0.5136 - val_loss: 2.4827 - val_categorical_accuracy: 0.2461
#
# Epoch 00023: val_categorical_accuracy did not improve from 0.25935
# Epoch 24/30
# 10240/10240 [==============================] - 8s 827us/step - loss: 1.0831 - categorical_accuracy: 0.5322 - val_loss: 2.6952 - val_categorical_accuracy: 0.2407
#
# Epoch 00024: val_categorical_accuracy did not improve from 0.25935
# Epoch 25/30
# 10240/10240 [==============================] - 9s 830us/step - loss: 1.0735 - categorical_accuracy: 0.5339 - val_loss: 2.5496 - val_categorical_accuracy: 0.2508
#
# Epoch 00025: val_categorical_accuracy did not improve from 0.25935
# Epoch 26/30
# 10240/10240 [==============================] - 9s 837us/step - loss: 1.0533 - categorical_accuracy: 0.5437 - val_loss: 2.5977 - val_categorical_accuracy: 0.2422
#
# Epoch 00026: val_categorical_accuracy did not improve from 0.25935
# Epoch 27/30
# 10240/10240 [==============================] - 9s 847us/step - loss: 1.0333 - categorical_accuracy: 0.5564 - val_loss: 2.7401 - val_categorical_accuracy: 0.2391
#
# Epoch 00027: val_categorical_accuracy did not improve from 0.25935
# Epoch 28/30
# 10240/10240 [==============================] - 9s 904us/step - loss: 1.0345 - categorical_accuracy: 0.5526 - val_loss: 2.9583 - val_categorical_accuracy: 0.2531
#
# Epoch 00028: val_categorical_accuracy did not improve from 0.25935
# Epoch 29/30
# 10240/10240 [==============================] - 9s 842us/step - loss: 1.0216 - categorical_accuracy: 0.5563 - val_loss: 2.7849 - val_categorical_accuracy: 0.2399
#
# Epoch 00029: val_categorical_accuracy did not improve from 0.25935
# Epoch 30/30
# 10240/10240 [==============================] - 9s 836us/step - loss: 0.9940 - categorical_accuracy: 0.5710 - val_loss: 3.1313 - val_categorical_accuracy: 0.2407
#
# Epoch 00030: val_categorical_accuracy did not improve from 0.25935
#
# Running iteration 3/5
# Train on 10240 samples, validate on 1284 samples
# Epoch 1/30
# 10240/10240 [==============================] - 10s 946us/step - loss: 0.9602 - categorical_accuracy: 0.5912 - val_loss: 2.9589 - val_categorical_accuracy: 0.2586
#
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.25857, saving model to model-3.h5
# Epoch 2/30
# 10240/10240 [==============================] - 9s 841us/step - loss: 0.9530 - categorical_accuracy: 0.5967 - val_loss: 3.0053 - val_categorical_accuracy: 0.2445
#
# Epoch 00002: val_categorical_accuracy did not improve from 0.25857
# Epoch 3/30
# 10240/10240 [==============================] - 9s 845us/step - loss: 0.9367 - categorical_accuracy: 0.6101 - val_loss: 2.9348 - val_categorical_accuracy: 0.2438
#
# Epoch 00003: val_categorical_accuracy did not improve from 0.25857
# Epoch 4/30
# 10240/10240 [==============================] - 9s 847us/step - loss: 0.9250 - categorical_accuracy: 0.6102 - val_loss: 2.8813 - val_categorical_accuracy: 0.2500
#
# Epoch 00004: val_categorical_accuracy did not improve from 0.25857
# Epoch 5/30
# 10240/10240 [==============================] - 9s 844us/step - loss: 0.9100 - categorical_accuracy: 0.6237 - val_loss: 3.2324 - val_categorical_accuracy: 0.2375
#
# Epoch 00005: val_categorical_accuracy did not improve from 0.25857
# Epoch 6/30
# 10240/10240 [==============================] - 8s 808us/step - loss: 0.8936 - categorical_accuracy: 0.6277 - val_loss: 3.0800 - val_categorical_accuracy: 0.2360
#
# Epoch 00006: val_categorical_accuracy did not improve from 0.25857
# Epoch 7/30
# 10240/10240 [==============================] - 8s 809us/step - loss: 0.8560 - categorical_accuracy: 0.6496 - val_loss: 3.0980 - val_categorical_accuracy: 0.2391
#
# Epoch 00007: val_categorical_accuracy did not improve from 0.25857
# Epoch 8/30
# 10240/10240 [==============================] - 8s 817us/step - loss: 0.8486 - categorical_accuracy: 0.6535 - val_loss: 3.2696 - val_categorical_accuracy: 0.2290
#
# Epoch 00008: val_categorical_accuracy did not improve from 0.25857
# Epoch 9/30
# 10240/10240 [==============================] - 8s 813us/step - loss: 0.8449 - categorical_accuracy: 0.6565 - val_loss: 3.3477 - val_categorical_accuracy: 0.2375
#
# Epoch 00009: val_categorical_accuracy did not improve from 0.25857
# Epoch 10/30
# 10240/10240 [==============================] - 8s 812us/step - loss: 0.8106 - categorical_accuracy: 0.6740 - val_loss: 3.2132 - val_categorical_accuracy: 0.2484
#
# Epoch 00010: val_categorical_accuracy did not improve from 0.25857
# Epoch 11/30
# 10240/10240 [==============================] - 8s 805us/step - loss: 0.8043 - categorical_accuracy: 0.6754 - val_loss: 3.8196 - val_categorical_accuracy: 0.2298
#
# Epoch 00011: val_categorical_accuracy did not improve from 0.25857
# Epoch 12/30
# 10240/10240 [==============================] - 8s 817us/step - loss: 0.7804 - categorical_accuracy: 0.6976 - val_loss: 3.9020 - val_categorical_accuracy: 0.2305
#
# Epoch 00012: val_categorical_accuracy did not improve from 0.25857
# Epoch 13/30
# 10240/10240 [==============================] - 8s 810us/step - loss: 0.7887 - categorical_accuracy: 0.6929 - val_loss: 3.4311 - val_categorical_accuracy: 0.2360
#
# Epoch 00013: val_categorical_accuracy did not improve from 0.25857
# Epoch 14/30
# 10240/10240 [==============================] - 8s 811us/step - loss: 0.7381 - categorical_accuracy: 0.7093 - val_loss: 3.5022 - val_categorical_accuracy: 0.2305
#
# Epoch 00014: val_categorical_accuracy did not improve from 0.25857
# Epoch 15/30
# 10240/10240 [==============================] - 8s 812us/step - loss: 0.7309 - categorical_accuracy: 0.7173 - val_loss: 4.2024 - val_categorical_accuracy: 0.2321
#
# Epoch 00015: val_categorical_accuracy did not improve from 0.25857
# Epoch 16/30
# 10240/10240 [==============================] - 8s 810us/step - loss: 0.7356 - categorical_accuracy: 0.7157 - val_loss: 3.7538 - val_categorical_accuracy: 0.2360
#
# Epoch 00016: val_categorical_accuracy did not improve from 0.25857
# Epoch 17/30
# 10240/10240 [==============================] - 8s 815us/step - loss: 0.6825 - categorical_accuracy: 0.7355 - val_loss: 3.7245 - val_categorical_accuracy: 0.2274
#
# Epoch 00017: val_categorical_accuracy did not improve from 0.25857
# Epoch 18/30
# 10240/10240 [==============================] - 8s 812us/step - loss: 0.6863 - categorical_accuracy: 0.7391 - val_loss: 3.8166 - val_categorical_accuracy: 0.2290
#
# Epoch 00018: val_categorical_accuracy did not improve from 0.25857
# Epoch 19/30
# 10240/10240 [==============================] - 8s 816us/step - loss: 0.6635 - categorical_accuracy: 0.7536 - val_loss: 3.9658 - val_categorical_accuracy: 0.2336
#
# Epoch 00019: val_categorical_accuracy did not improve from 0.25857
# Epoch 20/30
# 10240/10240 [==============================] - 8s 811us/step - loss: 0.6498 - categorical_accuracy: 0.7513 - val_loss: 4.3063 - val_categorical_accuracy: 0.2212
#
# Epoch 00020: val_categorical_accuracy did not improve from 0.25857
# Epoch 21/30
# 10240/10240 [==============================] - 8s 826us/step - loss: 0.6370 - categorical_accuracy: 0.7565 - val_loss: 4.4120 - val_categorical_accuracy: 0.2235
#
# Epoch 00021: val_categorical_accuracy did not improve from 0.25857
# Epoch 22/30
# 10240/10240 [==============================] - 9s 849us/step - loss: 0.6135 - categorical_accuracy: 0.7702 - val_loss: 3.6844 - val_categorical_accuracy: 0.2344
#
# Epoch 00022: val_categorical_accuracy did not improve from 0.25857
# Epoch 23/30
# 10240/10240 [==============================] - 9s 849us/step - loss: 0.6071 - categorical_accuracy: 0.7719 - val_loss: 4.2412 - val_categorical_accuracy: 0.2298
#
# Epoch 00023: val_categorical_accuracy did not improve from 0.25857
# Epoch 24/30
# 10240/10240 [==============================] - 9s 842us/step - loss: 0.6107 - categorical_accuracy: 0.7727 - val_loss: 4.0806 - val_categorical_accuracy: 0.2391
#
# Epoch 00024: val_categorical_accuracy did not improve from 0.25857
# Epoch 25/30
# 10240/10240 [==============================] - 9s 841us/step - loss: 0.5760 - categorical_accuracy: 0.7902 - val_loss: 4.0231 - val_categorical_accuracy: 0.2461
#
# Epoch 00025: val_categorical_accuracy did not improve from 0.25857
# Epoch 26/30
# 10240/10240 [==============================] - 9s 851us/step - loss: 0.5813 - categorical_accuracy: 0.7905 - val_loss: 4.2531 - val_categorical_accuracy: 0.2235
#
# Epoch 00026: val_categorical_accuracy did not improve from 0.25857
# Epoch 27/30
# 10240/10240 [==============================] - 8s 828us/step - loss: 0.5629 - categorical_accuracy: 0.7993 - val_loss: 4.5561 - val_categorical_accuracy: 0.2352
#
# Epoch 00027: val_categorical_accuracy did not improve from 0.25857
# Epoch 28/30
# 10240/10240 [==============================] - 9s 838us/step - loss: 0.5583 - categorical_accuracy: 0.8002 - val_loss: 4.3465 - val_categorical_accuracy: 0.2352
#
# Epoch 00028: val_categorical_accuracy did not improve from 0.25857
# Epoch 29/30
# 10240/10240 [==============================] - 9s 857us/step - loss: 0.5280 - categorical_accuracy: 0.8104 - val_loss: 4.4669 - val_categorical_accuracy: 0.2329
#
# Epoch 00029: val_categorical_accuracy did not improve from 0.25857
# Epoch 30/30
# 10240/10240 [==============================] - 9s 837us/step - loss: 0.5285 - categorical_accuracy: 0.8114 - val_loss: 4.5590 - val_categorical_accuracy: 0.2227
#
# Epoch 00030: val_categorical_accuracy did not improve from 0.25857
#
# Running iteration 4/5
# Train on 10240 samples, validate on 1284 samples
# Epoch 1/30
# 10240/10240 [==============================] - 10s 930us/step - loss: 0.4904 - categorical_accuracy: 0.8237 - val_loss: 4.8971 - val_categorical_accuracy: 0.2344
#
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.23442, saving model to model-4.h5
# Epoch 2/30
# 10240/10240 [==============================] - 9s 848us/step - loss: 0.4974 - categorical_accuracy: 0.8248 - val_loss: 4.6935 - val_categorical_accuracy: 0.2204
#
# Epoch 00002: val_categorical_accuracy did not improve from 0.23442
# Epoch 3/30
# 10240/10240 [==============================] - 8s 830us/step - loss: 0.4764 - categorical_accuracy: 0.8324 - val_loss: 4.7342 - val_categorical_accuracy: 0.2188
#
# Epoch 00003: val_categorical_accuracy did not improve from 0.23442
# Epoch 4/30
# 10240/10240 [==============================] - 8s 779us/step - loss: 0.4623 - categorical_accuracy: 0.8356 - val_loss: 4.8241 - val_categorical_accuracy: 0.2243
#
# Epoch 00004: val_categorical_accuracy did not improve from 0.23442
# Epoch 5/30
# 10240/10240 [==============================] - 8s 769us/step - loss: 0.4561 - categorical_accuracy: 0.8390 - val_loss: 4.4929 - val_categorical_accuracy: 0.2298
#
# Epoch 00005: val_categorical_accuracy did not improve from 0.23442
# Epoch 6/30
# 10240/10240 [==============================] - 8s 769us/step - loss: 0.4558 - categorical_accuracy: 0.8382 - val_loss: 4.8849 - val_categorical_accuracy: 0.2251
#
# Epoch 00006: val_categorical_accuracy did not improve from 0.23442
# Epoch 7/30
# 10240/10240 [==============================] - 8s 769us/step - loss: 0.4402 - categorical_accuracy: 0.8499 - val_loss: 4.6161 - val_categorical_accuracy: 0.2266
#
# Epoch 00007: val_categorical_accuracy did not improve from 0.23442
# Epoch 8/30
# 10240/10240 [==============================] - 8s 768us/step - loss: 0.4284 - categorical_accuracy: 0.8474 - val_loss: 5.3073 - val_categorical_accuracy: 0.2298
#
# Epoch 00008: val_categorical_accuracy did not improve from 0.23442
# Epoch 9/30
# 10240/10240 [==============================] - 8s 769us/step - loss: 0.4329 - categorical_accuracy: 0.8479 - val_loss: 5.0874 - val_categorical_accuracy: 0.2188
# Epoch 00009: val_categorical_accuracy did not improve from 0.23442
# Epoch 10/30
# 10240/10240 [==============================] - 8s 788us/step - loss: 0.4247 - categorical_accuracy: 0.8524 - val_loss: 4.7208 - val_categorical_accuracy: 0.2212
#
# Epoch 00010: val_categorical_accuracy did not improve from 0.23442
# Epoch 11/30
# 10240/10240 [==============================] - 8s 766us/step - loss: 0.4125 - categorical_accuracy: 0.8558 - val_loss: 5.5217 - val_categorical_accuracy: 0.2220
#
# Epoch 00011: val_categorical_accuracy did not improve from 0.23442
# Epoch 12/30
# 10240/10240 [==============================] - 8s 770us/step - loss: 0.4077 - categorical_accuracy: 0.8612 - val_loss: 4.9475 - val_categorical_accuracy: 0.2344
#
# Epoch 00012: val_categorical_accuracy did not improve from 0.23442
# Epoch 13/30
# 10240/10240 [==============================] - 8s 779us/step - loss: 0.3920 - categorical_accuracy: 0.8662 - val_loss: 5.0280 - val_categorical_accuracy: 0.2212
#
# Epoch 00013: val_categorical_accuracy did not improve from 0.23442
# Epoch 14/30
# 10240/10240 [==============================] - 8s 774us/step - loss: 0.3786 - categorical_accuracy: 0.8723 - val_loss: 4.8757 - val_categorical_accuracy: 0.2375
#
# Epoch 00014: val_categorical_accuracy improved from 0.23442 to 0.23754, saving model to model-4.h5
# Epoch 15/30
# 10240/10240 [==============================] - 8s 775us/step - loss: 0.3571 - categorical_accuracy: 0.8784 - val_loss: 5.1005 - val_categorical_accuracy: 0.2212
#
# Epoch 00015: val_categorical_accuracy did not improve from 0.23754
# Epoch 16/30
# 10240/10240 [==============================] - 8s 767us/step - loss: 0.3796 - categorical_accuracy: 0.8711 - val_loss: 5.2483 - val_categorical_accuracy: 0.2266
#
# Epoch 00016: val_categorical_accuracy did not improve from 0.23754
# Epoch 17/30
# 10240/10240 [==============================] - 8s 768us/step - loss: 0.3650 - categorical_accuracy: 0.8768 - val_loss: 5.0585 - val_categorical_accuracy: 0.2305
#
# Epoch 00017: val_categorical_accuracy did not improve from 0.23754
# Epoch 18/30
# 10240/10240 [==============================] - 8s 768us/step - loss: 0.3733 - categorical_accuracy: 0.8763 - val_loss: 5.2383 - val_categorical_accuracy: 0.2072
#
# Epoch 00018: val_categorical_accuracy did not improve from 0.23754
# Epoch 19/30
# 10240/10240 [==============================] - 8s 764us/step - loss: 0.3606 - categorical_accuracy: 0.8765 - val_loss: 5.2948 - val_categorical_accuracy: 0.2282
#
# Epoch 00019: val_categorical_accuracy did not improve from 0.23754
# Epoch 20/30
# 10240/10240 [==============================] - 8s 772us/step - loss: 0.3409 - categorical_accuracy: 0.8863 - val_loss: 5.7136 - val_categorical_accuracy: 0.2142
#
# Epoch 00020: val_categorical_accuracy did not improve from 0.23754
# Epoch 21/30
# 10240/10240 [==============================] - 8s 775us/step - loss: 0.3626 - categorical_accuracy: 0.8763 - val_loss: 5.3418 - val_categorical_accuracy: 0.2383
#
# Epoch 00021: val_categorical_accuracy improved from 0.23754 to 0.23832, saving model to model-4.h5
# Epoch 22/30
# 10240/10240 [==============================] - 8s 773us/step - loss: 0.3410 - categorical_accuracy: 0.8884 - val_loss: 5.6486 - val_categorical_accuracy: 0.2352
#
# Epoch 00022: val_categorical_accuracy did not improve from 0.23832
# Epoch 23/30
# 10240/10240 [==============================] - 8s 765us/step - loss: 0.3198 - categorical_accuracy: 0.8931 - val_loss: 5.4223 - val_categorical_accuracy: 0.2188
#
# Epoch 00023: val_categorical_accuracy did not improve from 0.23832
# Epoch 24/30
# 10240/10240 [==============================] - 8s 766us/step - loss: 0.3137 - categorical_accuracy: 0.9015 - val_loss: 5.6858 - val_categorical_accuracy: 0.2251
#
# Epoch 00024: val_categorical_accuracy did not improve from 0.23832
# Epoch 25/30
# 10240/10240 [==============================] - 8s 772us/step - loss: 0.2994 - categorical_accuracy: 0.9043 - val_loss: 6.0684 - val_categorical_accuracy: 0.2313
#
# Epoch 00025: val_categorical_accuracy did not improve from 0.23832
# Epoch 26/30
# 10240/10240 [==============================] - 8s 769us/step - loss: 0.3276 - categorical_accuracy: 0.8991 - val_loss: 5.2439 - val_categorical_accuracy: 0.2344
#
# Epoch 00026: val_categorical_accuracy did not improve from 0.23832
# Epoch 27/30
# 10240/10240 [==============================] - 8s 766us/step - loss: 0.3144 - categorical_accuracy: 0.8979 - val_loss: 5.5435 - val_categorical_accuracy: 0.2243
#
# Epoch 00027: val_categorical_accuracy did not improve from 0.23832
# Epoch 28/30
# 10240/10240 [==============================] - 8s 769us/step - loss: 0.3028 - categorical_accuracy: 0.9029 - val_loss: 5.7766 - val_categorical_accuracy: 0.2274
#
# Epoch 00028: val_categorical_accuracy did not improve from 0.23832
# Epoch 29/30
# 10240/10240 [==============================] - 8s 767us/step - loss: 0.2966 - categorical_accuracy: 0.9025 - val_loss: 5.6763 - val_categorical_accuracy: 0.2204
#
# Epoch 00029: val_categorical_accuracy did not improve from 0.23832
# Epoch 30/30
# 10240/10240 [==============================] - 8s 772us/step - loss: 0.2977 - categorical_accuracy: 0.9022 - val_loss: 6.0460 - val_categorical_accuracy: 0.2196
#
# Epoch 00030: val_categorical_accuracy did not improve from 0.23832
#
# Running iteration 5/5
# Train on 10240 samples, validate on 1284 samples
# Epoch 1/30
# 10240/10240 [==============================] - 9s 862us/step - loss: 0.2832 - categorical_accuracy: 0.9121 - val_loss: 5.5430 - val_categorical_accuracy: 0.2157
#
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.21573, saving model to model-5.h5
# Epoch 2/30
# 10240/10240 [==============================] - 8s 768us/step - loss: 0.2925 - categorical_accuracy: 0.9066 - val_loss: 5.4634 - val_categorical_accuracy: 0.2126
#
# Epoch 00002: val_categorical_accuracy did not improve from 0.21573
# Epoch 3/30
# 10240/10240 [==============================] - 8s 768us/step - loss: 0.2781 - categorical_accuracy: 0.9112 - val_loss: 5.5367 - val_categorical_accuracy: 0.2220
#
# Epoch 00003: val_categorical_accuracy improved from 0.21573 to 0.22196, saving model to model-5.h5
# Epoch 4/30
# 10240/10240 [==============================] - 8s 771us/step - loss: 0.2810 - categorical_accuracy: 0.9105 - val_loss: 5.6940 - val_categorical_accuracy: 0.2118
#
# Epoch 00004: val_categorical_accuracy did not improve from 0.22196
# Epoch 5/30
# 10240/10240 [==============================] - 8s 763us/step - loss: 0.2867 - categorical_accuracy: 0.9090 - val_loss: 5.6464 - val_categorical_accuracy: 0.2243
#
# Epoch 00005: val_categorical_accuracy improved from 0.22196 to 0.22430, saving model to model-5.h5
# Epoch 6/30
# 10240/10240 [==============================] - 8s 768us/step - loss: 0.3008 - categorical_accuracy: 0.9049 - val_loss: 5.4296 - val_categorical_accuracy: 0.2344
#
# Epoch 00006: val_categorical_accuracy improved from 0.22430 to 0.23442, saving model to model-5.h5
# Epoch 7/30
# 10240/10240 [==============================] - 8s 765us/step - loss: 0.2883 - categorical_accuracy: 0.9080 - val_loss: 5.3478 - val_categorical_accuracy: 0.2188
#
# Epoch 00007: val_categorical_accuracy did not improve from 0.23442
# Epoch 8/30
# 10240/10240 [==============================] - 8s 768us/step - loss: 0.2620 - categorical_accuracy: 0.9174 - val_loss: 5.9031 - val_categorical_accuracy: 0.2196
#
# Epoch 00008: val_categorical_accuracy did not improve from 0.23442
# Epoch 9/30
# 10240/10240 [==============================] - 8s 769us/step - loss: 0.2784 - categorical_accuracy: 0.9126 - val_loss: 5.6973 - val_categorical_accuracy: 0.2235
#
# Epoch 00009: val_categorical_accuracy did not improve from 0.23442
# Epoch 10/30
# 10240/10240 [==============================] - 8s 767us/step - loss: 0.2712 - categorical_accuracy: 0.9173 - val_loss: 5.8401 - val_categorical_accuracy: 0.2243
#
# Epoch 00010: val_categorical_accuracy did not improve from 0.23442
# Epoch 11/30
# 10240/10240 [==============================] - 9s 836us/step - loss: 0.2362 - categorical_accuracy: 0.9276 - val_loss: 5.7741 - val_categorical_accuracy: 0.2282
#
# Epoch 00011: val_categorical_accuracy did not improve from 0.23442
# Epoch 12/30
# 10240/10240 [==============================] - 9s 841us/step - loss: 0.2427 - categorical_accuracy: 0.9237 - val_loss: 6.1204 - val_categorical_accuracy: 0.2150
# Epoch 00012: val_categorical_accuracy did not improve from 0.23442
# Epoch 13/30
# 10240/10240 [==============================] - 8s 817us/step - loss: 0.2522 - categorical_accuracy: 0.9209 - val_loss: 5.6914 - val_categorical_accuracy: 0.2227
#
# Epoch 00013: val_categorical_accuracy did not improve from 0.23442
# Epoch 14/30
# 10240/10240 [==============================] - 8s 802us/step - loss: 0.2509 - categorical_accuracy: 0.9257 - val_loss: 6.0376 - val_categorical_accuracy: 0.2196
#
# Epoch 00014: val_categorical_accuracy did not improve from 0.23442
# Epoch 15/30
# 10240/10240 [==============================] - 8s 801us/step - loss: 0.2319 - categorical_accuracy: 0.9295 - val_loss: 5.7747 - val_categorical_accuracy: 0.2274
#
# Epoch 00015: val_categorical_accuracy did not improve from 0.23442
# Epoch 16/30
# 10240/10240 [==============================] - 8s 805us/step - loss: 0.2448 - categorical_accuracy: 0.9234 - val_loss: 5.8660 - val_categorical_accuracy: 0.2251
#
# Epoch 00016: val_categorical_accuracy did not improve from 0.23442
# Epoch 17/30
# 10240/10240 [==============================] - 8s 802us/step - loss: 0.2504 - categorical_accuracy: 0.9254 - val_loss: 5.7666 - val_categorical_accuracy: 0.2157
#
# Epoch 00017: val_categorical_accuracy did not improve from 0.23442
# Epoch 18/30
# 10240/10240 [==============================] - 8s 803us/step - loss: 0.2559 - categorical_accuracy: 0.9233 - val_loss: 5.5949 - val_categorical_accuracy: 0.2282
#
# Epoch 00018: val_categorical_accuracy did not improve from 0.23442
# Epoch 19/30
# 10240/10240 [==============================] - 8s 819us/step - loss: 0.2422 - categorical_accuracy: 0.9286 - val_loss: 6.4854 - val_categorical_accuracy: 0.2212
#
# Epoch 00019: val_categorical_accuracy did not improve from 0.23442
# Epoch 20/30
# 10240/10240 [==============================] - 8s 806us/step - loss: 0.2419 - categorical_accuracy: 0.9256 - val_loss: 6.1840 - val_categorical_accuracy: 0.2243
#
# Epoch 00020: val_categorical_accuracy did not improve from 0.23442
# Epoch 21/30
# 10240/10240 [==============================] - 8s 807us/step - loss: 0.2201 - categorical_accuracy: 0.9330 - val_loss: 6.0612 - val_categorical_accuracy: 0.2142
#
# Epoch 00021: val_categorical_accuracy did not improve from 0.23442
# Epoch 22/30
# 10240/10240 [==============================] - 8s 813us/step - loss: 0.2423 - categorical_accuracy: 0.9249 - val_loss: 5.9418 - val_categorical_accuracy: 0.2259
#
# Epoch 00022: val_categorical_accuracy did not improve from 0.23442
# Epoch 23/30
# 10240/10240 [==============================] - 8s 823us/step - loss: 0.2340 - categorical_accuracy: 0.9327 - val_loss: 6.3218 - val_categorical_accuracy: 0.2103
#
# Epoch 00023: val_categorical_accuracy did not improve from 0.23442
# Epoch 24/30
# 10240/10240 [==============================] - 8s 810us/step - loss: 0.2198 - categorical_accuracy: 0.9321 - val_loss: 6.0111 - val_categorical_accuracy: 0.2103
#
# Epoch 00024: val_categorical_accuracy did not improve from 0.23442
# Epoch 25/30
# 10240/10240 [==============================] - 8s 807us/step - loss: 0.2430 - categorical_accuracy: 0.9265 - val_loss: 5.8537 - val_categorical_accuracy: 0.2181
#
# Epoch 00025: val_categorical_accuracy did not improve from 0.23442
# Epoch 26/30
# 10240/10240 [==============================] - 8s 812us/step - loss: 0.2183 - categorical_accuracy: 0.9352 - val_loss: 6.1378 - val_categorical_accuracy: 0.2251
#
# Epoch 00026: val_categorical_accuracy did not improve from 0.23442
# Epoch 27/30
# 10240/10240 [==============================] - 8s 807us/step - loss: 0.2173 - categorical_accuracy: 0.9371 - val_loss: 5.9056 - val_categorical_accuracy: 0.2103
#
# Epoch 00027: val_categorical_accuracy did not improve from 0.23442
# Epoch 28/30
# 10240/10240 [==============================] - 8s 818us/step - loss: 0.2125 - categorical_accuracy: 0.9369 - val_loss: 5.8483 - val_categorical_accuracy: 0.2227
#
# Epoch 00028: val_categorical_accuracy did not improve from 0.23442
# Epoch 29/30
# 10240/10240 [==============================] - 8s 828us/step - loss: 0.2187 - categorical_accuracy: 0.9315 - val_loss: 6.3092 - val_categorical_accuracy: 0.2212
#
# Epoch 00029: val_categorical_accuracy did not improve from 0.23442
# Epoch 30/30
# 10240/10240 [==============================] - 8s 811us/step - loss: 0.2257 - categorical_accuracy: 0.9340 - val_loss: 6.0464 - val_categorical_accuracy: 0.2204
#
# Epoch 00030: val_categorical_accuracy did not improve from 0.23442

# %%
### plot the output
with open('history22.pkl', 'wb') as f:
    cPickle.dump(histArr, f)

# %%
histArr = cPickle.load(open('history22.pkl', 'rb'))

# %%
def get_avg(histArr, his_key):
    tmp = []
    for history in histArr:
        tmp.append(history[his_key][np.argmin(history['val_loss'])])
    return np.mean(tmp)
    
print('Training: \t%0.4f loss / %0.4f acc' % (get_avg(histArr, 'loss'),
                                              get_avg(histArr, 'categorical_accuracy')))
print('Validation: \t%0.4f loss / %0.4f acc' % (get_avg(histArr, 'val_loss'),
                                                get_avg(histArr, 'val_categorical_accuracy')))
# Out:
# Training: 	0.9742 loss / 0.5956 acc
# Validation: 	3.2286 loss / 0.2396 acc

# %%
def plot_acc_loss(title, histArr, key_acc, key_loss):
    fig, (ax1, ax2) = plt.subplots(1, 2)
    # Accuracy
    ax1.set_title('Model accuracy (%s)' % title)
    names = []
    for i, model in enumerate(histArr):
        ax1.plot(model[key_acc])
        ax1.set_xlabel('epoch')
        names.append('Model %i' % (i+1))
        ax1.set_ylabel('accuracy')
    ax1.legend(names, loc='lower right')
    # Loss
    ax2.set_title('Model loss (%s)' % title)
    for model in histArr:
        ax2.plot(model[key_loss])
        ax2.set_xlabel('epoch')
        ax2.set_ylabel('loss')
    ax2.legend(names, loc='upper right')
    fig.set_size_inches(20, 5)
    plt.show()

# %%
plot_acc_loss('training', histArr, 'categorical_accuracy', 'loss')
plot_acc_loss('validation', histArr, 'val_categorical_accuracy', 'val_loss')

# %%
### Make prediction
from keras.models import load_model
#Load a pre-trained model if any
model1 = load_model('weights.best.hdf5')
preds = model1.predict([x_test,x_test_metadata], batch_size=batch_size, verbose=1)
print(np.array(preds))

# %%
# from keras.utils.np_utils import accuracy
# acc = accuracy(y_test, np.round(np.array(preds)))

# %% [markdown]
# ###  C-LSTM model for fake news classification
#
# To better understand performance gap between different convolutional models, here I want to see Convolutional -LSTM model for fake news classification. Note that I didn't run multiple convolutional filers for fake news texts because it raise strange error, so I'll proceed somehow simple but powerful model for fake news classification.

# %%
## C-LSTM model implementation (trail version)
from keras.layers import LSTM
from keras.optimizers import Adam
from keras.layers import LSTM, Bidirectional

statement_input = Input(shape=(num_steps,), dtype='int64', name='main_input')
# embed_layer = Embedding(output_dim=hidden_size, input_dim=vocab_length+1, input_length=num_steps)(statement_input) #Train embeddings from scratch
embed_layer = Embedding(vocab_length+1,embedding_dims,weights=[embedding_weights],input_length=num_steps,trainable=False)(statement_input) #Preloaded glove embeddings
l_lstm = Bidirectional(LSTM(100, return_sequences=True, dropout=0.25, recurrent_dropout=0.1))(embed_layer)

## let's add convolutional layer on it
l_conv1 = Conv1D(128, 3, activation="relu")(l_lstm)
l_pool1 = MaxPooling1D(3)(l_conv1)
l_conv2 = Conv1D(128,3,activation="relu")(l_pool1)
l_pool2 = MaxPool1D(3)(l_conv2)
l_flat = Flatten()(l_pool2)

# l_pool = GlobalMaxPool1D()(l_lstm)
l_drop = Dropout(0.6)(l_flat)
conv_in = Dense(hidden_size, activation="relu")(l_drop)

### metadata
meta_input = Input(shape=(x_train_metadata.shape[1],), name='aux_input')
x_meta_hidden = Dense(64, activation='relu')(meta_input)
x_meta_reg = Dropout(0.6)(x_meta_hidden)

conv_final = keras.layers.concatenate([conv_in, x_meta_reg])
model_output = Dense(6, activation='softmax', name='main_output')(conv_final)
model_CLSTM = Model(inputs=[statement_input, meta_input], outputs=[model_output])

## compile model
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model_CLSTM.compile(optimizer=sgd,
                    loss='categorical_crossentropy',
                    metrics=['categorical_accuracy'])

model_CLSTM.summary()

tb = TensorBoard()
csv_logger = keras.callbacks.CSVLogger('training.log')
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=2)
filepath= "weights.best.hdf5"
checkpoint = keras.callbacks.ModelCheckpoint(filepath, 
                                             monitor='val_categorical_accuracy', 
                                             verbose=1, save_best_only=True, mode='max')

history_clstm = model_CLSTM.fit({'main_input': x_train, 'aux_input': x_train_metadata},
                                {'main_output': y_train},epochs=num_epochs, batch_size=batch_size,
                                validation_data=({'main_input': x_val, 'aux_input': x_val_metadata},{'main_output': y_val}),
                                callbacks=[tb,csv_logger,checkpoint, es])
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# main_input (InputLayer)         (None, 64)           0
# __________________________________________________________________________________________________
# embedding_5 (Embedding)         (None, 64, 300)      3722700     main_input[0][0]
# __________________________________________________________________________________________________
# bidirectional_4 (Bidirectional) (None, 64, 200)      320800      embedding_5[0][0]
# __________________________________________________________________________________________________
# conv1d_9 (Conv1D)               (None, 62, 128)      76928       bidirectional_4[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_9 (MaxPooling1D)  (None, 20, 128)      0           conv1d_9[0][0]
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, 18, 128)      49280       max_pooling1d_9[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_10 (MaxPooling1D) (None, 6, 128)       0           conv1d_10[0][0]
# __________________________________________________________________________________________________
# flatten_7 (Flatten)             (None, 768)          0           max_pooling1d_10[0][0]
# __________________________________________________________________________________________________
# aux_input (InputLayer)          (None, 94)           0
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 768)          0           flatten_7[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 64)           6080        aux_input[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 100)          76900       dropout_13[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 64)           0           dense_10[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 164)          0           dense_9[0][0]
#                                                                  dropout_14[0][0]
# __________________________________________________________________________________________________
# main_output (Dense)             (None, 6)            990         concatenate_6[0][0]
# ==================================================================================================
# Total params: 4,253,678
# Trainable params: 530,978
# Non-trainable params: 3,722,700
# __________________________________________________________________________________________________
# Train on 10240 samples, validate on 1284 samples
# Epoch 1/30
# 10240/10240 [==============================] - 45s 4ms/step - loss: 1.7658 - categorical_accuracy: 0.2028 - val_loss: 1.7453 - val_categorical_accuracy: 0.2103
#
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.21028, saving model to weights.best.hdf5
# Epoch 2/30
# 10240/10240 [==============================] - 50s 5ms/step - loss: 1.7451 - categorical_accuracy: 0.2211 - val_loss: 1.7294 - val_categorical_accuracy: 0.2422
#
# Epoch 00002: val_categorical_accuracy improved from 0.21028 to 0.24221, saving model to weights.best.hdf5
# Epoch 3/30
# 10240/10240 [==============================] - 47s 5ms/step - loss: 1.7281 - categorical_accuracy: 0.2368 - val_loss: 1.7056 - val_categorical_accuracy: 0.2547
#
# Epoch 00003: val_categorical_accuracy improved from 0.24221 to 0.25467, saving model to weights.best.hdf5
# Epoch 4/30
# 10240/10240 [==============================] - 42s 4ms/step - loss: 1.7118 - categorical_accuracy: 0.2497 - val_loss: 1.6929 - val_categorical_accuracy: 0.2664
#
# Epoch 00004: val_categorical_accuracy improved from 0.25467 to 0.26636, saving model to weights.best.hdf5
# Epoch 5/30
# 10240/10240 [==============================] - 43s 4ms/step - loss: 1.7057 - categorical_accuracy: 0.2521 - val_loss: 1.6891 - val_categorical_accuracy: 0.2632
#
# Epoch 00005: val_categorical_accuracy did not improve from 0.26636
# Epoch 6/30
# 10240/10240 [==============================] - 42s 4ms/step - loss: 1.7007 - categorical_accuracy: 0.2582 - val_loss: 1.6871 - val_categorical_accuracy: 0.2710
#
# Epoch 00006: val_categorical_accuracy improved from 0.26636 to 0.27103, saving model to weights.best.hdf5
# Epoch 7/30
# 10240/10240 [==============================] - 42s 4ms/step - loss: 1.6961 - categorical_accuracy: 0.2593 - val_loss: 1.6853 - val_categorical_accuracy: 0.2617
#
# Epoch 00007: val_categorical_accuracy did not improve from 0.27103
# Epoch 8/30
# 10240/10240 [==============================] - 42s 4ms/step - loss: 1.6909 - categorical_accuracy: 0.2653 - val_loss: 1.6768 - val_categorical_accuracy: 0.2710
#
# Epoch 00008: val_categorical_accuracy did not improve from 0.27103
# Epoch 9/30
# 10240/10240 [==============================] - 42s 4ms/step - loss: 1.6836 - categorical_accuracy: 0.2722 - val_loss: 1.6687 - val_categorical_accuracy: 0.2726
#
# Epoch 00009: val_categorical_accuracy improved from 0.27103 to 0.27259, saving model to weights.best.hdf5
# Epoch 10/30
# 10240/10240 [==============================] - 43s 4ms/step - loss: 1.6784 - categorical_accuracy: 0.2730 - val_loss: 1.6731 - val_categorical_accuracy: 0.2812
#
# Epoch 00010: val_categorical_accuracy improved from 0.27259 to 0.28115, saving model to weights.best.hdf5
# Epoch 11/30
# 10240/10240 [==============================] - 41s 4ms/step - loss: 1.6743 - categorical_accuracy: 0.2758 - val_loss: 1.6723 - val_categorical_accuracy: 0.2726
#
# Epoch 00011: val_categorical_accuracy did not improve from 0.28115
# Epoch 00011: early stopping

# %%
### visualize c-lstm model output
accu_curve=plt.figure()
plt.plot(history_clstm.history['categorical_accuracy'],'r',linewidth=3.0)
plt.plot(history_clstm.history['val_categorical_accuracy'],'b',linewidth=3.0)
plt.legend(['Training Accuracy', 'Validation Accuracy'],fontsize=12)
plt.xlabel('Epochs ',fontsize=12)
plt.ylabel('Accuracy',fontsize=12)
plt.title('Accuracy Curves : C-LSTM',fontsize=12)
accu_curve.savefig('accuracy_clstm_improved_v1.4.png')
plt.show()
##^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^##
loss_curve = plt.figure()
plt.plot(history_clstm.history['loss'],'r',linewidth=3.0)
plt.plot(history_clstm.history['val_loss'],'b',linewidth=3.0)
plt.legend(['Training loss', 'Validation Loss'],fontsize=12)
plt.xlabel('Epochs ',fontsize=12)
plt.ylabel('Loss',fontsize=12)
plt.title('Loss Curves :C-LSTM',fontsize=12)
loss_curve.savefig('loss_clstm_improved_v1.4.png')
loss_curve.show()

# %% [markdown]
# ## ## Improvised version of C-LSTM model for fake news classification

# %%
from keras.layers import LSTM
from keras.optimizers import Adam
from keras.layers import LSTM, Bidirectional

##+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++##
kernel_arr = []
statement_input = Input(shape=(num_steps,), dtype='int32', name='main_input')
embed_sequences = Embedding(vocab_length+1,embedding_dims,weights=[embedding_weights],input_length=num_steps,trainable=False)(statement_input) #Preloaded glove embeddings
# x = Embedding(output_dim=hidden_size, input_dim=vocab_length+1, input_length=num_steps)(statement_input) #Train embeddings from scratch

for kernel in kernel_sizes:
    x_1 = Conv1D(filters=filter_size,kernel_size=kernel, 
                 padding="same", activation="relu", strides=1)(embed_sequences)
    x_pool = MaxPool1D(2)(x_1)
    #x_pool = GlobalMaxPool1D()(x_1)
    x_flat = Flatten()(x_pool)
    #x_drop = Dropout(0.7)(x_flat)
    kernel_arr.append(x_flat)

conv_in = keras.layers.concatenate(kernel_arr)
conv_in = Dropout(0.85)(conv_in)
conv_in = Dense(128, activation='relu')(conv_in)

## use bidirectional lstm
x_lstm = Bidirectional(LSTM(100, return_sequences=True, dropout=0.25, recurrent_dropout=0.1))(x_1)
lstm_pool = GlobalMaxPool1D()(x_lstm)
lstm_dense = Dense(100, activation="relu")(lstm_pool)

## first concatenate
conv_ins= keras.layers.concatenate([conv_in, lstm_dense])

#Meta input
meta_input = Input(shape=(x_train_metadata.shape[1],), name='aux_input')
x_drop = Dropout(0.7)(meta_input)
x_meta = Dense(100, activation='relu')(x_drop)
x = keras.layers.concatenate([conv_ins,x_meta])

main_output = Dense(6, activation='softmax', name='main_output')(x)
model_clstm = Model(inputs=[statement_input, meta_input], outputs=[main_output])


## compile model
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model_clstm.compile(optimizer=sgd,
                    loss='categorical_crossentropy',
                    metrics=['categorical_accuracy'])


model_clstm.summary()

##+++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++##
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# main_input (InputLayer)         (None, 64)           0
# __________________________________________________________________________________________________
# embedding_6 (Embedding)         (None, 64, 300)      3722700     main_input[0][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, 64, 128)      76928       embedding_6[0][0]
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, 64, 128)      115328      embedding_6[0][0]
# __________________________________________________________________________________________________
# conv1d_13 (Conv1D)              (None, 64, 128)      192128      embedding_6[0][0]
# __________________________________________________________________________________________________
# conv1d_14 (Conv1D)              (None, 64, 128)      268928      embedding_6[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_11 (MaxPooling1D) (None, 32, 128)      0           conv1d_11[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_12 (MaxPooling1D) (None, 32, 128)      0           conv1d_12[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_13 (MaxPooling1D) (None, 32, 128)      0           conv1d_13[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_14 (MaxPooling1D) (None, 32, 128)      0           conv1d_14[0][0]
# __________________________________________________________________________________________________
# flatten_8 (Flatten)             (None, 4096)         0           max_pooling1d_11[0][0]
# __________________________________________________________________________________________________
# flatten_9 (Flatten)             (None, 4096)         0           max_pooling1d_12[0][0]
# __________________________________________________________________________________________________
# flatten_10 (Flatten)            (None, 4096)         0           max_pooling1d_13[0][0]
# __________________________________________________________________________________________________
# flatten_11 (Flatten)            (None, 4096)         0           max_pooling1d_14[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 16384)        0           flatten_8[0][0]
#                                                                  flatten_9[0][0]
#                                                                  flatten_10[0][0]
#                                                                  flatten_11[0][0]
# __________________________________________________________________________________________________
# bidirectional_5 (Bidirectional) (None, 64, 200)      183200      conv1d_14[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 16384)        0           concatenate_7[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_2 (GlobalM (None, 200)          0           bidirectional_5[0][0]
# __________________________________________________________________________________________________
# aux_input (InputLayer)          (None, 94)           0
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 128)          2097280     dropout_15[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 100)          20100       global_max_pooling1d_2[0][0]
# __________________________________________________________________________________________________
# dropout_16 (Dropout)            (None, 94)           0           aux_input[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 228)          0           dense_11[0][0]
#                                                                  dense_12[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 100)          9500        dropout_16[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 328)          0           concatenate_8[0][0]
#                                                                  dense_13[0][0]
# __________________________________________________________________________________________________
# main_output (Dense)             (None, 6)            1974        concatenate_9[0][0]
# ==================================================================================================
# Total params: 6,688,066
# Trainable params: 2,965,366
# Non-trainable params: 3,722,700
# __________________________________________________________________________________________________

# %% [markdown]
# ### Character level CNN model for fake news classification

# %%
import tensorflow as tf
from keras import layers
from keras import backend as K
from math import sqrt
K.set_image_dim_ordering('th')

from keras import Model
from keras.layers import Input, Dense, Concatenate, Embedding, Flatten
from keras.layers import AlphaDropout
from keras.layers import ThresholdedReLU
from keras.callbacks import TensorBoard
from keras.layers import Convolution1D, GlobalMaxPooling1D

# %%
import os
os.environ['KERAS_BACKEND'] = 'theano'
import keras as K

# %% [markdown]
# #### character level classification (simple version)

# %%
conv_layers=[[256, 7, 3],
             [256, 7, 3],
             [256, 3, -1],
             [256, 3, -1],
             [256, 3, -1],
             [256, 3, 3]]

fully_connected_layers=[1024, 1024]
dropout_p=0.5
threshold=1e-06
input_size=70
alphabet='abcdefghijklmnopqrstuvwxyz0123456789-,;.!?:\'"/\\|_@#$%^&*~`+-=<>()[]{}'

batch_size=128
checkpoint_every=70
epochs=5000
# evaluate_every=100
batch_size=128
checkpoint_every=100
epochs=5000
# evaluate_every=100
embedding_size=128
alphabet_size=69

# %%
## define model input, create embedding layer
sent_inputs = Input(shape=(input_size,), name='sent_input', dtype='int64')  # shape=(?, 1014)

conv = Embedding(alphabet_size+1, embedding_size, input_length=input_size, trainable=False)(sent_inputs)
# Conv 
conv_lay=[]
for filter_num, filter_size, pooling_size in conv_layers:
    x_conv = Conv1D(filter_num, filter_size, padding="same")(conv) 
    x_pool  = GlobalMaxPooling1D()(x_conv)
    x_drop = Dropout(0.6)(x_pool)
    conv_lay.append(x_drop)
#     if pooling_size != -1:
#         conv = MaxPooling1D(pool_size=pooling_size)(conv) # Final shape=(None, 34, 256)

# x = Flatten()(conv_lay) # (None, 8704)
x=concatenate(conv_lay)

# Fully connected layers 
for dense_size in fully_connected_layers:
    x = Dense(dense_size, activation='relu')(x) # dense_size == 1024
    x = Dropout(dropout_p)(x)
    
model_output = Dense(6, activation='softmax')(x)
# Build model
adam = Adam(lr=1e-4, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.2)

model_char = Model(inputs=sent_inputs, outputs=model_output)
model_char.compile(optimizer=adam,
                  loss='categorical_crossentropy',
                  metrics=['categorical_accuracy'])

model_char.summary()
tb = TensorBoard()
csv_logger = keras.callbacks.CSVLogger('training.log')
es=EarlyStopping(monitor="val_loss", mode='min', verbose=1, patience=3 )
filepath= "weights.best.hdf5"
checkpoint = keras.callbacks.ModelCheckpoint(filepath, 
                                             monitor='val_categorical_accuracy', 
                                             verbose=1, save_best_only=True, mode='max')


# history_char= model_char.fit(x_train,y_train,epochs=num_epochs, batch_size=batch_size,
#                                validation_data=(x_val,y_val))

# %%
x_train.shape
# Out:
# (10240, 70)

# %%
model_char.fit(x_train,y_train,epochs=10, batch_size=64, validation_data=(x_val, y_val))

# %% [markdown]
# ### Recurrent CNN model for fake news classification

# %%
import gensim
import numpy as np
import string
import gensim
from gensim.models import Word2Vec
from gensim.utils import simple_preprocess
from gensim.models.keyedvectors import KeyedVectors

# %%
word2vec = KeyedVectors.load_word2vec_format('GoogleNews-vectors-negative300.bin', binary=True)

# %%
word2vec.syn0.shape[0]
word2vec.syn0.shape[1]

# %%
# word2vec = gensim.models.Word2Vec.load("word2vec.gensim")
embeddings = np.zeros((word2vec.syn0.shape[0] + 1, word2vec.syn0.shape[1]), dtype = "float32")
embeddings[:word2vec.syn0.shape[0]] = word2vec.syn0

MAX_TOKENS = word2vec.syn0.shape[0]
embedding_dim = word2vec.syn0.shape[1]
hidden_dim_1 = 200
hidden_dim_2 = 100
NUM_CLASSES = 10

document = Input(shape = (None, ), dtype = "int32")
left_context = Input(shape = (None, ), dtype = "int32")
right_context = Input(shape = (None, ), dtype = "int32")

embedder = Embedding(MAX_TOKENS + 1, embedding_dim, weights = [embeddings], trainable = False)
doc_embedding = embedder(document)
l_embedding = embedder(left_context)
r_embedding = embedder(right_context)

forward = LSTM(hidden_dim_1, return_sequences = True)(l_embedding)
backward = LSTM(hidden_dim_1, return_sequences = True, go_backwards = True)(r_embedding)

# Keras returns the output sequences in reverse order.
backward = Lambda(lambda x: backend.reverse(x, axes = 1))(backward)
together = concatenate([forward, doc_embedding, backward], axis = 2)

semantic = Conv1D(hidden_dim_2, kernel_size = 1, activation = "tanh")(together)

## define customized maxpooling layer
pool_rnn = Lambda(lambda x: backend.max(x, axis = 1), output_shape = (hidden_dim_2, ))(semantic)
model_output = Dense(NUM_CLASSES, input_dim = hidden_dim_2, activation = "softmax")(pool_rnn)

## define and compile RCNN mode
RCNN_model = Model(inputs = [document, left_context, right_context], outputs = model_output)
model.compile(optimizer = "adadelta", loss = "categorical_crossentropy", metrics = ["accuracy"])


adam = Adam(lr=1e-4, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.2)
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
RCNN_model.compile(optimizer=sgd,
                   loss='categorical_crossentropy',
                   metrics=['categorical_accuracy'])

RCNN_model.summary()

tb = TensorBoard()
csv_logger = keras.callbacks.CSVLogger('training.log')
filepath= "weights.best.hdf5"
checkpoint = keras.callbacks.ModelCheckpoint(filepath, 
                                             monitor='val_categorical_accuracy', 
                                             verbose=1, save_best_only=True, mode='max')

history_rcnn= RCNN_model.fit({'main_input': x_train, 'aux_input': x_train_metadata},
                             {'main_output': y_train},epochs=num_epochs, batch_size=batch_size,
                             validation_data=({'main_input': x_val, 'aux_input': x_val_metadata},{'main_output': y_val}),
                             callbacks=[tb,csv_logger,checkpoint])

# %%
text = "This is some example text."
text = text.strip().lower().translate(str.maketrans({key: " {0} ".format(key) for key in string.punctuation}))
tokens = text.split()
tokens = [word2vec.vocab[token].index if token in word2vec.vocab else MAX_TOKENS for token in tokens]

doc_as_array = np.array([tokens])
# We shift the document to the right to obtain the left-side contexts.
left_context_as_array = np.array([[MAX_TOKENS] + tokens[:-1]])
# We shift the document to the left to obtain the right-side contexts.
right_context_as_array = np.array([tokens[1:] + [MAX_TOKENS]])

target = np.array([NUM_CLASSES * [0]])
target[0][3] = 1

history = model.fit([doc_as_array, left_context_as_array, right_context_as_array], target, epochs = 1, verbose = 0)
loss = history.history["loss"][0]
